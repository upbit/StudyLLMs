# %%
import asyncio
import requests
from datetime import datetime, timedelta
from enum import Enum

NEWS_API_KEY = "3fc1f6647e6b4aaa9fc7aec282a27ea4"

class SortBy(Enum):
    popularity = "popularity"
    relevancy = "relevancy" 
    publishedAt = "publishedAt"

async def _news_api(
    query: str,
    num_articles: int = 50,
    sort_by: SortBy = SortBy.relevancy,
    last_day = 30,
) -> dict:
    # 免费账号限制，只能获取最近1月数据
    today = datetime.now()
    one_month_ago = today - timedelta(days=last_day)
    from_datetime = one_month_ago.strftime("%Y-%m-%d")

    # https://newsapi.org/v2/everything?q=Apple&from=2023-07-29&sortBy=popularity
    response = requests.get(
        "https://newsapi.org/v2/everything",
        params={
            "q": query,
            "apiKey": NEWS_API_KEY,
            "pageSize": num_articles,
            "sortBy": sort_by,
            "from": from_datetime,
        },
    )
    return response.json()['articles']

# await _news_api("OpenAI", 10, sort_by=SortBy.publishedAt, last_day=7), # 1周内最新10条
# await _news_api("OpenAI", 10, sort_by=SortBy.popularity), # 1月内最热10条
# await _news_api("OpenAI", 10, sort_by=SortBy.popularity, last_day=7)

# %%
import math
import itertools
from loguru import logger
from tqdm.auto import tqdm

async def search_news(queries, batch_size=4):
    def get_chunks(inputs, size):
        batches = []
        for item in inputs:
            batches.append(item)
            if len(batches) == batch_size:
                yield batches
                batches = [] 
        if batches:
            yield batches

    documents = {}
    chunks = get_chunks(queries, batch_size)
    for qs in tqdm(chunks, total=math.ceil(len(queries)/batch_size)):
        logger.debug(f"Search news: {qs}")
        coros = [ _news_api(query, num_articles=20, last_day=7) for query in qs ]
        results = await asyncio.gather(*coros)

        for articles in results:
            for doc in articles:
                doc_key = doc['title']
                logger.info(f"  Get [{doc_key}]")
                documents[doc_key] = doc

    return documents

# News about LLaMA2
queries = [
    "LLaMA2 news",
    "LLaMA2 latest developments",
    "LLaMA2 updates",
    "LLaMA2 new features",
    "LLaMA2 release",
    "LLaMA2 release date",
    "LLaMA2 beta",
    "LLaMA2 launch",
    "LLaMA2 availability",
    "LLaMA2 rumors",
    "LLaMA2 speculations",
    "LLaMA2 leaks",
    "LLaMA2 product review",
    "LLaMA2 comparison",
    "LLaMA2 vs competitors",
    "LLaMA2 pricing",
    "LLaMA2 sales",
    "LLaMA2 market share",
    "LLaMA2 impact on industry",
    "LLaMA2 customer reviews",
    "LLaMA2 reliability",
    "LLaMA2 security",
    "LLaMA2 performance",
    "LLaMA2 compatibility",
    "LLaMA2 integration",
    "LLaMA2 case studies",
    "LLaMA2 use cases",
    "LLaMA2 benefits",
    "LLaMA2 drawbacks",
    "LLaMA2 future prospects",
    "LLaMA2 innovation",
    "LLaMA2 technology",
    "LLaMA2 advancements",
]

docs = await search_news(queries)
len(docs)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# 2023-07-29 21:41:37.383 | DEBUG    | __main__:search_news:20 - Search news: ['LLaMA2 news', 'LLaMA2 latest developments', 'LLaMA2 updates', 'LLaMA2 new features']
# 2023-07-29 21:41:42.013 | INFO     | __main__:search_news:27 -   Get [Hugging News #0724: Llama 2 登陆 Hugging Face、AI 开源游戏竞赛获奖选手公布！ - HuggingFace]
# 2023-07-29 21:41:42.014 | INFO     | __main__:search_news:27 -   Get [Daily Hacker News for 2023-07-23]
# 2023-07-29 21:41:42.014 | INFO     | __main__:search_news:27 -   Get [How Meta’s Llama 2 Shifts Marketing’s Relationship With AI]
# 2023-07-29 21:41:42.015 | INFO     | __main__:search_news:27 -   Get [Llama2.c: inference llama 2 in one file of pure C | Hacker News]
# 2023-07-29 21:41:42.016 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:41:42.016 | INFO     | __main__:search_news:27 -   Get [4 big analyst picks: Meta lands a buy rating on AI By]
# 2023-07-29 21:41:42.017 | INFO     | __main__:search_news:27 -   Get [Meta Stock: Facebook Parent Beats Q2 Goals]
# 2023-07-29 21:41:42.017 | INFO     | __main__:search_news:27 -   Get [AWS Week in Review – Redshift+Forecast, CodeCatalyst+GitHub, Lex Analytics, Llama 2, and Much More – July 24, 2023]
# 2023-07-29 21:41:42.018 | INFO     | __main__:search_news:27 -   Get [Alibaba Cloud to Support Meta AI Model for Chinese Users]
# 2023-07-29 21:41:42.018 | INFO     | __main__:search_news:27 -   Get [Unsupervised Learning NO. 391]
# 2023-07-29 21:41:42.019 | INFO     | __main__:search_news:27 -   Get [Will Biden’s Meetings with A.I. Companies Make Any Difference?]
# 2023-07-29 21:41:42.019 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:41:42.019 | INFO     | __main__:search_news:27 -   Get [Alibaba#39;s cloud unit brings Meta#39;s AI model Llama to its clients]
# 2023-07-29 21:41:42.020 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:41:42.020 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:41:42.021 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:41:42.022 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:41:42.022 | INFO     | __main__:search_news:27 -   Get [Llama2.c: inference llama 2 in one file of pure C | Hacker News]
# 2023-07-29 21:41:42.023 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:41:42.023 | INFO     | __main__:search_news:27 -   Get [AWS Week in Review – Redshift+Forecast, CodeCatalyst+GitHub, Lex Analytics, Llama 2, and Much More – July 24, 2023]
# 2023-07-29 21:41:42.024 | INFO     | __main__:search_news:27 -   Get [This Week In Rust: This Week in Rust 505]
# 2023-07-29 21:41:42.024 | INFO     | __main__:search_news:27 -   Get [How Meta’s Llama 2 Shifts Marketing’s Relationship With AI]
# 2023-07-29 21:41:42.025 | INFO     | __main__:search_news:27 -   Get [Running Language Models – Deploy Llama2 7b on AI Core]
# 2023-07-29 21:41:42.025 | INFO     | __main__:search_news:27 -   Get [The Future of Programming: AI and Interface-Oriented Languages]
# 2023-07-29 21:41:42.026 | INFO     | __main__:search_news:27 -   Get [This Week In Rust: This Week in Rust 505]
# 2023-07-29 21:41:42.026 | INFO     | __main__:search_news:27 -   Get [gentopia added to PyPI]
# 2023-07-29 21:41:42.027 | DEBUG    | __main__:search_news:20 - Search news: ['LLaMA2 release', 'LLaMA2 release date', 'LLaMA2 beta', 'LLaMA2 launch']
# 2023-07-29 21:41:46.293 | INFO     | __main__:search_news:27 -   Get [LLaMA2 Chat 70B outperformed ChatGPT]
# 2023-07-29 21:41:46.294 | INFO     | __main__:search_news:27 -   Get [How Meta’s Llama 2 Shifts Marketing’s Relationship With AI]
# 2023-07-29 21:41:46.295 | INFO     | __main__:search_news:27 -   Get [Meta Platforms Stock Gets Upgraded Going Into Earnings - Here's Why]
# 2023-07-29 21:41:46.295 | INFO     | __main__:search_news:27 -   Get [8 Ways to Try Llama 2 from Meta for Free]
# 2023-07-29 21:41:46.296 | INFO     | __main__:search_news:27 -   Get [Running Language Models – Deploy Llama2 7b on AI Core]
# 2023-07-29 21:41:46.296 | INFO     | __main__:search_news:27 -   Get [LLAMA2: Testing a Tiny LLM with Hugging Face & SAP BTP]
# 2023-07-29 21:41:46.297 | INFO     | __main__:search_news:27 -   Get [Simplify your LLM Chatbot Demos with SAP BTP and Gradio]
# 2023-07-29 21:41:46.297 | INFO     | __main__:search_news:27 -   Get [Show HN: Goat-7B LLM, a new SOTA among the open-source 7B models]
# 2023-07-29 21:41:46.298 | INFO     | __main__:search_news:27 -   Get [Llama We Doing This Again?]
# 2023-07-29 21:41:46.298 | INFO     | __main__:search_news:27 -   Get [Alibaba Cloud to Support Meta AI Model for Chinese Users]
# 2023-07-29 21:41:46.299 | INFO     | __main__:search_news:27 -   Get [Unsupervised Learning NO. 391]
# 2023-07-29 21:41:46.299 | INFO     | __main__:search_news:27 -   Get [A comprehensive guide to running Llama 2 locally]
# 2023-07-29 21:41:46.300 | INFO     | __main__:search_news:27 -   Get [The Unprecedented Surge of AI by Big Tech]
# 2023-07-29 21:41:46.300 | INFO     | __main__:search_news:27 -   Get [How Meta’s Llama 2 Shifts Marketing’s Relationship With AI]
# 2023-07-29 21:41:46.301 | INFO     | __main__:search_news:27 -   Get [A Silent New AI Bombshell Launch Nobody Saw Coming]
# 2023-07-29 21:41:46.301 | INFO     | __main__:search_news:27 -   Get [What is LLama2? : Dive into Meta AI’s Newest Open Source Language Model]
# 2023-07-29 21:41:46.302 | INFO     | __main__:search_news:27 -   Get [Meta reports Q2 revenue up 11% YoY to $32B, net income up 16% YoY to $7.79B, and family daily active people up 7% YoY to 3.07B for June 2023]
# 2023-07-29 21:41:46.303 | INFO     | __main__:search_news:27 -   Get [Meta plans retention 'hooks' for Threads as more than half of users leave app]
# 2023-07-29 21:41:46.303 | INFO     | __main__:search_news:27 -   Get [Meta plans retention 'hooks' for Threads as more than half of users leave app]
# 2023-07-29 21:41:46.304 | INFO     | __main__:search_news:27 -   Get [Meta plans retention 'hooks' for Threads as more than half of users leave app]
# 2023-07-29 21:41:46.304 | INFO     | __main__:search_news:27 -   Get [AWS Week in Review – Redshift+Forecast, CodeCatalyst+GitHub, Lex Analytics, Llama 2, and Much More – July 24, 2023]
# 2023-07-29 21:41:46.305 | DEBUG    | __main__:search_news:20 - Search news: ['LLaMA2 availability', 'LLaMA2 rumors', 'LLaMA2 speculations', 'LLaMA2 leaks']
# 2023-07-29 21:41:50.473 | INFO     | __main__:search_news:27 -   Get [How Meta’s Llama 2 Shifts Marketing’s Relationship With AI]
# 2023-07-29 21:41:50.473 | INFO     | __main__:search_news:27 -   Get [The Unprecedented Surge of AI by Big Tech]
# 2023-07-29 21:41:50.474 | INFO     | __main__:search_news:27 -   Get [Llama We Doing This Again?]
# 2023-07-29 21:41:50.475 | DEBUG    | __main__:search_news:20 - Search news: ['LLaMA2 product review', 'LLaMA2 comparison', 'LLaMA2 vs competitors', 'LLaMA2 pricing']
# 2023-07-29 21:41:54.664 | INFO     | __main__:search_news:27 -   Get [LLaMA2 Chat 70B outperformed ChatGPT]
# 2023-07-29 21:41:54.664 | INFO     | __main__:search_news:27 -   Get [Llama2.c: inference llama 2 in one file of pure C]
# 2023-07-29 21:41:54.665 | INFO     | __main__:search_news:27 -   Get [Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕]
# 2023-07-29 21:41:54.666 | INFO     | __main__:search_news:27 -   Get [8 Ways to Try Llama 2 from Meta for Free]
# 2023-07-29 21:41:54.666 | INFO     | __main__:search_news:27 -   Get [Llama We Doing This Again?]
# 2023-07-29 21:41:54.667 | DEBUG    | __main__:search_news:20 - Search news: ['LLaMA2 sales', 'LLaMA2 market share', 'LLaMA2 impact on industry', 'LLaMA2 customer reviews']
# 2023-07-29 21:41:58.692 | INFO     | __main__:search_news:27 -   Get [Meta (NASDAQ:META) Surprises With Q2 Sales, Stock Soars]
# 2023-07-29 21:41:58.692 | INFO     | __main__:search_news:27 -   Get [Meta Leaps As Zuckerberg Touts AI Pipeline In Solid Earnings, Outlook]
# 2023-07-29 21:41:58.693 | INFO     | __main__:search_news:27 -   Get [Meta Stock: Facebook Parent Beats Q2 Goals]
# 2023-07-29 21:41:58.693 | INFO     | __main__:search_news:27 -   Get [Will Biden’s Meetings with A.I. Companies Make Any Difference?]
# 2023-07-29 21:41:58.694 | DEBUG    | __main__:search_news:20 - Search news: ['LLaMA2 reliability', 'LLaMA2 security', 'LLaMA2 performance', 'LLaMA2 compatibility']
# 2023-07-29 21:42:02.602 | INFO     | __main__:search_news:27 -   Get [Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕]
# 2023-07-29 21:42:02.603 | INFO     | __main__:search_news:27 -   Get [How Meta’s Llama 2 Shifts Marketing’s Relationship With AI]
# 2023-07-29 21:42:02.603 | INFO     | __main__:search_news:27 -   Get [Google, Microsoft, Amazon, Meta Pledge to Make AI Safer and More Secure]
# 2023-07-29 21:42:02.604 | INFO     | __main__:search_news:27 -   Get [Unsupervised Learning NO. 391]
# 2023-07-29 21:42:02.604 | INFO     | __main__:search_news:27 -   Get [AWS Week in Review – Redshift+Forecast, CodeCatalyst+GitHub, Lex Analytics, Llama 2, and Much More – July 24, 2023]
# 2023-07-29 21:42:02.605 | INFO     | __main__:search_news:27 -   Get [Will Biden’s Meetings with A.I. Companies Make Any Difference?]
# 2023-07-29 21:42:02.605 | INFO     | __main__:search_news:27 -   Get [The Future of Programming: AI and Interface-Oriented Languages]
# 2023-07-29 21:42:02.606 | INFO     | __main__:search_news:27 -   Get [Simplify your LLM Chatbot Demos with SAP BTP and Gradio]
# 2023-07-29 21:42:02.606 | INFO     | __main__:search_news:27 -   Get [Llama We Doing This Again?]
# 2023-07-29 21:42:02.607 | INFO     | __main__:search_news:27 -   Get [How Meta’s Llama 2 Shifts Marketing’s Relationship With AI]
# 2023-07-29 21:42:02.607 | INFO     | __main__:search_news:27 -   Get [Facebook parent Meta sees advertising jump, tops Wall Street targets]
# 2023-07-29 21:42:02.608 | INFO     | __main__:search_news:27 -   Get [Running Language Models – Deploy Llama2 7b on AI Core]
# 2023-07-29 21:42:02.608 | INFO     | __main__:search_news:27 -   Get [AWS Week in Review – Redshift+Forecast, CodeCatalyst+GitHub, Lex Analytics, Llama 2, and Much More – July 24, 2023]
# 2023-07-29 21:42:02.608 | INFO     | __main__:search_news:27 -   Get [This Week In Rust: This Week in Rust 505]
# 2023-07-29 21:42:02.609 | INFO     | __main__:search_news:27 -   Get [Show HN: LLM Boxing – GPT 3.5 vs. Llama 2]
# 2023-07-29 21:42:02.610 | INFO     | __main__:search_news:27 -   Get [Llama We Doing This Again?]
# 2023-07-29 21:42:02.610 | INFO     | __main__:search_news:27 -   Get [This Week In Rust: This Week in Rust 505]
# 2023-07-29 21:42:02.611 | DEBUG    | __main__:search_news:20 - Search news: ['LLaMA2 integration', 'LLaMA2 case studies', 'LLaMA2 use cases', 'LLaMA2 benefits']
# 2023-07-29 21:42:06.319 | INFO     | __main__:search_news:27 -   Get [Alibaba to support Meta’s AI model Llama - report]
# 2023-07-29 21:42:06.320 | INFO     | __main__:search_news:27 -   Get [AWS Week in Review – Redshift+Forecast, CodeCatalyst+GitHub, Lex Analytics, Llama 2, and Much More – July 24, 2023]
# 2023-07-29 21:42:06.320 | INFO     | __main__:search_news:27 -   Get [Google versus Microsoft versus Meta - Warum der Kampf um die KI-Vorherrschaft gut für Nutzer ist]
# 2023-07-29 21:42:06.321 | INFO     | __main__:search_news:27 -   Get [How Meta’s Llama 2 Shifts Marketing’s Relationship With AI]
# 2023-07-29 21:42:06.321 | INFO     | __main__:search_news:27 -   Get [Generative AI set to infuse $450B into enterprise sector – reports]
# 2023-07-29 21:42:06.322 | INFO     | __main__:search_news:27 -   Get [Llama We Doing This Again?]
# 2023-07-29 21:42:06.322 | INFO     | __main__:search_news:27 -   Get [Generative AI set to infuse $450B into enterprise sector – reports]
# 2023-07-29 21:42:06.322 | INFO     | __main__:search_news:27 -   Get [The Future of Programming: AI and Interface-Oriented Languages]
# 2023-07-29 21:42:06.323 | DEBUG    | __main__:search_news:20 - Search news: ['LLaMA2 drawbacks', 'LLaMA2 future prospects', 'LLaMA2 innovation', 'LLaMA2 technology']
# 2023-07-29 21:42:10.224 | INFO     | __main__:search_news:27 -   Get [Meta’s Llama AI Model Now Accessible to Alibaba Cloud’s Customers]
# 2023-07-29 21:42:10.225 | INFO     | __main__:search_news:27 -   Get [Unsupervised Learning NO. 391]
# 2023-07-29 21:42:10.225 | INFO     | __main__:search_news:27 -   Get [The Unprecedented Surge of AI by Big Tech]
# 2023-07-29 21:42:10.226 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:42:10.226 | INFO     | __main__:search_news:27 -   Get [Alibaba#39;s cloud unit brings Meta#39;s AI model Llama to its clients]
# 2023-07-29 21:42:10.227 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:42:10.227 | INFO     | __main__:search_news:27 -   Get [Alibaba to support Meta’s AI model Llama - report]
# 2023-07-29 21:42:10.227 | INFO     | __main__:search_news:27 -   Get [Meta Platforms Q2 Earnings Highlights: Revenue And EPS Beat, Guidance Update, Lower Costs, 'Compelling' AI Opportunity]
# 2023-07-29 21:42:10.228 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:42:10.228 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:42:10.228 | INFO     | __main__:search_news:27 -   Get [Facing more nimble rivals, OpenAI won’t bend … yet]
# 2023-07-29 21:42:10.229 | INFO     | __main__:search_news:27 -   Get [What Led Mark Zuckerberg's Meta To Team Up With Microsoft On ChatGPT-Rival Llama-2]
# 2023-07-29 21:42:10.229 | INFO     | __main__:search_news:27 -   Get [Meta exec Nick Clegg on AI: "I definitely think you need regulation"]
# 2023-07-29 21:42:10.229 | INFO     | __main__:search_news:27 -   Get [Alibaba's cloud unit brings Meta's AI model Llama to its clients]
# 2023-07-29 21:42:10.230 | INFO     | __main__:search_news:27 -   Get [Generative AI set to infuse $450B into enterprise sector – reports]
# 2023-07-29 21:42:10.231 | INFO     | __main__:search_news:27 -   Get [Unsupervised Learning NO. 391]
# 2023-07-29 21:42:10.231 | INFO     | __main__:search_news:27 -   Get [Will Biden’s Meetings with A.I. Companies Make Any Difference?]
# 2023-07-29 21:42:10.232 | INFO     | __main__:search_news:27 -   Get [Llama We Doing This Again?]
# 2023-07-29 21:42:10.233 | DEBUG    | __main__:search_news:20 - Search news: ['LLaMA2 advancements']
# 44

# %%
import pandas as pd

df = pd.DataFrame(docs).transpose()
df.to_csv('last_documents.csv', encoding="utf-8")
df
# Out:
#                                                                                                source  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...                {'id': None, 'name': 'Cnblogs.com'}
# Daily Hacker News for 2023-07-23                              {'id': None, 'name': 'Daemonology.net'}
# How Meta’s Llama 2 Shifts Marketing’s Relations...                    {'id': None, 'name': 'CMSWire'}
# Llama2.c: inference llama 2 in one file of pure...       {'id': 'hacker-news', 'name': 'Hacker News'}
# Alibaba's cloud unit brings Meta's AI model Lla...  {'id': 'the-times-of-india', 'name': 'The Time...
# 4 big analyst picks: Meta lands a buy rating on...                 {'id': None, 'name': 'Biztoc.com'}
# Meta Stock: Facebook Parent Beats Q2 Goals                         {'id': None, 'name': 'Biztoc.com'}
# AWS Week in Review – Redshift+Forecast, CodeCat...                 {'id': None, 'name': 'Amazon.com'}
# Alibaba Cloud to Support Meta AI Model for Chin...               {'id': None, 'name': 'Investopedia'}
# Unsupervised Learning NO. 391                              {'id': None, 'name': 'Danielmiessler.com'}
# Will Biden’s Meetings with A.I. Companies Make ...             {'id': None, 'name': 'The New Yorker'}
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...               {'id': None, 'name': 'Moneycontrol'}
# This Week In Rust: This Week in Rust 505                {'id': None, 'name': 'This-week-in-rust.org'}
# Running Language Models – Deploy Llama2 7b on A...                    {'id': None, 'name': 'Sap.com'}
# The Future of Programming: AI and Interface-Ori...                     {'id': None, 'name': 'Medium'}
# gentopia added to PyPI                                               {'id': None, 'name': 'Pypi.org'}
# LLaMA2 Chat 70B outperformed ChatGPT                                {'id': None, 'name': 'Github.io'}
# Meta Platforms Stock Gets Upgraded Going Into E...                 {'id': None, 'name': 'Biztoc.com'}
# 8 Ways to Try Llama 2 from Meta for Free                {'id': None, 'name': 'Ilovefreesoftware.com'}
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...                    {'id': None, 'name': 'Sap.com'}
# Simplify your LLM Chatbot Demos with SAP BTP an...                    {'id': None, 'name': 'Sap.com'}
# Show HN: Goat-7B LLM, a new SOTA among the open...             {'id': None, 'name': 'Huggingface.co'}
# Llama We Doing This Again?                                      {'id': None, 'name': 'Lesswrong.com'}
# A comprehensive guide to running Llama 2 locally                {'id': None, 'name': 'Replicate.com'}
# The Unprecedented Surge of AI by Big Tech                  {'id': None, 'name': 'Web-strategist.com'}
# A Silent New AI Bombshell Launch Nobody Saw Coming                 {'id': None, 'name': 'Biztoc.com'}
# What is LLama2? : Dive into Meta AI’s Newest Op...                 {'id': None, 'name': 'Biztoc.com'}
# Meta reports Q2 revenue up 11% YoY to $32B, net...                 {'id': None, 'name': 'Biztoc.com'}
# Meta plans retention 'hooks' for Threads as mor...                 {'id': None, 'name': 'Biztoc.com'}
# Llama2.c: inference llama 2 in one file of pure C                  {'id': None, 'name': 'Github.com'}
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                               {'id': None, 'name': 'Cnblogs.com'}
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...                 {'id': None, 'name': 'Biztoc.com'}
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...                 {'id': None, 'name': 'Biztoc.com'}
# Google, Microsoft, Amazon, Meta Pledge to Make ...                 {'id': None, 'name': 'Biztoc.com'}
# Facebook parent Meta sees advertising jump, top...                 {'id': None, 'name': 'Biztoc.com'}
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2                       {'id': None, 'name': 'Llmboxing.com'}
# Alibaba to support Meta’s AI model Llama - report               {'id': None, 'name': 'Cointelegraph'}
# Google versus Microsoft versus Meta - Warum der...                   {'id': 'focus', 'name': 'Focus'}
# Generative AI set to infuse $450B into enterpri...                {'id': None, 'name': 'CryptoSlate'}
# Meta’s Llama AI Model Now Accessible to Alibaba...                 {'id': None, 'name': 'Biztoc.com'}
# Meta Platforms Q2 Earnings Highlights: Revenue ...                 {'id': None, 'name': 'Biztoc.com'}
# Facing more nimble rivals, OpenAI won’t bend … yet                 {'id': None, 'name': 'Biztoc.com'}
# What Led Mark Zuckerberg's Meta To Team Up With...                 {'id': None, 'name': 'Biztoc.com'}
# Meta exec Nick Clegg on AI: "I definitely think...                 {'id': None, 'name': 'Biztoc.com'}
#
#                                                                                author  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...                        HuggingFace
# Daily Hacker News for 2023-07-23                                                 None
# How Meta’s Llama 2 Shifts Marketing’s Relations...     pr@cmswire.com (Pierre DeBois)
# Llama2.c: inference llama 2 in one file of pure...                             tomcam
# Alibaba's cloud unit brings Meta's AI model Lla...                            Reuters
# 4 big analyst picks: Meta lands a buy rating on...                      investing.com
# Meta Stock: Facebook Parent Beats Q2 Goals                              investors.com
# AWS Week in Review – Redshift+Forecast, CodeCat...                          Jeff Barr
# Alibaba Cloud to Support Meta AI Model for Chin...                     Vaidik Trivedi
# Unsupervised Learning NO. 391                                         Daniel Miessler
# Will Biden’s Meetings with A.I. Companies Make ...                        Sue Halpern
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...                            Reuters
# This Week In Rust: This Week in Rust 505                            TWiR Contributors
# Running Language Models – Deploy Llama2 7b on A...                      Felix Bartler
# The Future of Programming: AI and Interface-Ori...                       Eric Elliott
# gentopia added to PyPI                                              billxbf@gmail.com
# LLaMA2 Chat 70B outperformed ChatGPT                                             None
# Meta Platforms Stock Gets Upgraded Going Into E...                       benzinga.com
# 8 Ways to Try Llama 2 from Meta for Free                             Mohammad Suleman
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...                     Aron MacDonald
# Simplify your LLM Chatbot Demos with SAP BTP an...                     Aron MacDonald
# Show HN: Goat-7B LLM, a new SOTA among the open...                          goat-zero
# Llama We Doing This Again?                                                        Zvi
# A comprehensive guide to running Llama 2 locally                               bfirsh
# The Unprecedented Surge of AI by Big Tech                             jeremiah_owyang
# A Silent New AI Bombshell Launch Nobody Saw Coming                         medium.com
# What is LLama2? : Dive into Meta AI’s Newest Op...      medium.datadriveninvestor.com
# Meta reports Q2 revenue up 11% YoY to $32B, net...                    investor.fb.com
# Meta plans retention 'hooks' for Threads as mor...                            aol.com
# Llama2.c: inference llama 2 in one file of pure C                            karpathy
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                                            沉睡的木木夕
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...                     stockstory.org
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...                      thestreet.com
# Google, Microsoft, Amazon, Meta Pledge to Make ...                           cnet.com
# Facebook parent Meta sees advertising jump, top...                            aol.com
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2                                Charlieholtz
# Alibaba to support Meta’s AI model Llama - report   Cointelegraph By Gareth Jenkinson
# Google versus Microsoft versus Meta - Warum der...   Von Gastautor Reinhard Schlieker
# Generative AI set to infuse $450B into enterpri...                Liam 'Akiba' Wright
# Meta’s Llama AI Model Now Accessible to Alibaba...                    coinspeaker.com
# Meta Platforms Q2 Earnings Highlights: Revenue ...                       benzinga.com
# Facing more nimble rivals, OpenAI won’t bend … yet                        semafor.com
# What Led Mark Zuckerberg's Meta To Team Up With...                       benzinga.com
# Meta exec Nick Clegg on AI: "I definitely think...                            aol.com
#
#                                                                                                 title  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  Hugging News #0724: Llama 2 登陆 Hugging Face、AI...
# Daily Hacker News for 2023-07-23                                     Daily Hacker News for 2023-07-23
# How Meta’s Llama 2 Shifts Marketing’s Relations...  How Meta’s Llama 2 Shifts Marketing’s Relation...
# Llama2.c: inference llama 2 in one file of pure...  Llama2.c: inference llama 2 in one file of pur...
# Alibaba's cloud unit brings Meta's AI model Lla...  Alibaba's cloud unit brings Meta's AI model Ll...
# 4 big analyst picks: Meta lands a buy rating on...  4 big analyst picks: Meta lands a buy rating o...
# Meta Stock: Facebook Parent Beats Q2 Goals                 Meta Stock: Facebook Parent Beats Q2 Goals
# AWS Week in Review – Redshift+Forecast, CodeCat...  AWS Week in Review – Redshift+Forecast, CodeCa...
# Alibaba Cloud to Support Meta AI Model for Chin...  Alibaba Cloud to Support Meta AI Model for Chi...
# Unsupervised Learning NO. 391                                           Unsupervised Learning NO. 391
# Will Biden’s Meetings with A.I. Companies Make ...  Will Biden’s Meetings with A.I. Companies Make...
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...  Alibaba#39;s cloud unit brings Meta#39;s AI mo...
# This Week In Rust: This Week in Rust 505                     This Week In Rust: This Week in Rust 505
# Running Language Models – Deploy Llama2 7b on A...  Running Language Models – Deploy Llama2 7b on ...
# The Future of Programming: AI and Interface-Ori...  The Future of Programming: AI and Interface-Or...
# gentopia added to PyPI                                                         gentopia added to PyPI
# LLaMA2 Chat 70B outperformed ChatGPT                             LLaMA2 Chat 70B outperformed ChatGPT
# Meta Platforms Stock Gets Upgraded Going Into E...  Meta Platforms Stock Gets Upgraded Going Into ...
# 8 Ways to Try Llama 2 from Meta for Free                     8 Ways to Try Llama 2 from Meta for Free
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...  LLAMA2: Testing a Tiny LLM with Hugging Face &...
# Simplify your LLM Chatbot Demos with SAP BTP an...  Simplify your LLM Chatbot Demos with SAP BTP a...
# Show HN: Goat-7B LLM, a new SOTA among the open...  Show HN: Goat-7B LLM, a new SOTA among the ope...
# Llama We Doing This Again?                                                 Llama We Doing This Again?
# A comprehensive guide to running Llama 2 locally     A comprehensive guide to running Llama 2 locally
# The Unprecedented Surge of AI by Big Tech                   The Unprecedented Surge of AI by Big Tech
# A Silent New AI Bombshell Launch Nobody Saw Coming  A Silent New AI Bombshell Launch Nobody Saw Co...
# What is LLama2? : Dive into Meta AI’s Newest Op...  What is LLama2? : Dive into Meta AI’s Newest O...
# Meta reports Q2 revenue up 11% YoY to $32B, net...  Meta reports Q2 revenue up 11% YoY to $32B, ne...
# Meta plans retention 'hooks' for Threads as mor...  Meta plans retention 'hooks' for Threads as mo...
# Llama2.c: inference llama 2 in one file of pure C   Llama2.c: inference llama 2 in one file of pure C
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                               Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...  Meta (NASDAQ:META) Surprises With Q2 Sales, St...
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...  Meta Leaps As Zuckerberg Touts AI Pipeline In ...
# Google, Microsoft, Amazon, Meta Pledge to Make ...  Google, Microsoft, Amazon, Meta Pledge to Make...
# Facebook parent Meta sees advertising jump, top...  Facebook parent Meta sees advertising jump, to...
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2                   Show HN: LLM Boxing – GPT 3.5 vs. Llama 2
# Alibaba to support Meta’s AI model Llama - report   Alibaba to support Meta’s AI model Llama - report
# Google versus Microsoft versus Meta - Warum der...  Google versus Microsoft versus Meta - Warum de...
# Generative AI set to infuse $450B into enterpri...  Generative AI set to infuse $450B into enterpr...
# Meta’s Llama AI Model Now Accessible to Alibaba...  Meta’s Llama AI Model Now Accessible to Alibab...
# Meta Platforms Q2 Earnings Highlights: Revenue ...  Meta Platforms Q2 Earnings Highlights: Revenue...
# Facing more nimble rivals, OpenAI won’t bend … yet  Facing more nimble rivals, OpenAI won’t bend …...
# What Led Mark Zuckerberg's Meta To Team Up With...  What Led Mark Zuckerberg's Meta To Team Up Wit...
# Meta exec Nick Clegg on AI: "I definitely think...  Meta exec Nick Clegg on AI: "I definitely thin...
#
#                                                                                           description  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  每一周，我们的同事都会向社区的成员们发布一些关于 Hugging Face 相关的更新，包括...
# Daily Hacker News for 2023-07-23                    The 10 highest-rated articles on\nHacker News\...
# How Meta’s Llama 2 Shifts Marketing’s Relations...  Learn how Meta’s Llama 2 is changing the marke...
# Llama2.c: inference llama 2 in one file of pure...                                               None
# Alibaba's cloud unit brings Meta's AI model Lla...  Alibaba's cloud computing division said it has...
# 4 big analyst picks: Meta lands a buy rating on...  Here is your Pro Recap of the biggest analyst ...
# Meta Stock: Facebook Parent Beats Q2 Goals          parent company of Facebook, Instagram and What...
# AWS Week in Review – Redshift+Forecast, CodeCat...  Summer is in full swing here in Seattle and we...
# Alibaba Cloud to Support Meta AI Model for Chin...  ADRs of Alibaba and Meta shares rose after the...
# Unsupervised Learning NO. 391                       AI Manipulation Defenders, .MIL Leak, and the ...
# Will Biden’s Meetings with A.I. Companies Make ...  Voluntary commitments from the likes of OpenAI...
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...  Meta released Llama2, a commercial version of ...
# This Week In Rust: This Week in Rust 505            Hello and welcome to another issue of This Wee...
# Running Language Models – Deploy Llama2 7b on A...  With the rapid release of new language models,...
# The Future of Programming: AI and Interface-Ori...  AI language models, such as ChatGPT and Claude...
# gentopia added to PyPI                              Gentopia provides extensive utilities to assem...
# LLaMA2 Chat 70B outperformed ChatGPT                                                         Comments
# Meta Platforms Stock Gets Upgraded Going Into E...  Meta Platforms Inc META shares are trading hig...
# 8 Ways to Try Llama 2 from Meta for Free            Here is a list of free websites where you can ...
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...  NOTE: The views and opinions expressed in this...
# Simplify your LLM Chatbot Demos with SAP BTP an...  NOTE: The views and opinions expressed in this...
# Show HN: Goat-7B LLM, a new SOTA among the open...  New research results around LLM 'alignment', d...
# Llama We Doing This Again?                          Published on July 26, 2023 1:00 PM GMTI’ve fin...
# A comprehensive guide to running Llama 2 locally    Article URL: https://replicate.com/blog/run-ll...
# The Unprecedented Surge of AI by Big Tech           Eight Significant AI Moves from Tech Giants in...
# A Silent New AI Bombshell Launch Nobody Saw Coming  A Silent New AI Bombshell Launch Nobody Saw Co...
# What is LLama2? : Dive into Meta AI’s Newest Op...  Meta AI and Microsoft have come together to la...
# Meta reports Q2 revenue up 11% YoY to $32B, net...  MENLO PARK, Calif., July 26, 2023 /PRNewswire/...
# Meta plans retention 'hooks' for Threads as mor...  Meta Platforms executives are heavily focused ...
# Llama2.c: inference llama 2 in one file of pure C   Inference Llama 2 in one file of pure C. Contr...
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                 # Llama 2：开放式基础和微调聊天模型 ## 写在前头 因为最近一直在使用 LLM 工...
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...  Social network operator Meta Platforms (NASDAQ...
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...  Updated at 4:24 pm EDT Meta Platforms (META) -...
# Google, Microsoft, Amazon, Meta Pledge to Make ...  The White House has secured "voluntary commitm...
# Facebook parent Meta sees advertising jump, top...  Meta Platforms on Wednesday reported a quick r...
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2           Article URL: https://llmboxing.com\nComments U...
# Alibaba to support Meta’s AI model Llama - report   Alibaba Cloud is reportedly set to integrate M...
# Google versus Microsoft versus Meta - Warum der...  In rasantem Tempo erobert künstliche Intellige...
# Generative AI set to infuse $450B into enterpri...  Generative Artificial Intelligence (AI) contin...
# Meta’s Llama AI Model Now Accessible to Alibaba...  Coinspeaker Meta’s Llama AI Model Now Accessib...
# Meta Platforms Q2 Earnings Highlights: Revenue ...  Technology company Meta Platforms META reporte...
# Facing more nimble rivals, OpenAI won’t bend … yet  The Scoop Customers have asked to run OpenAI m...
# What Led Mark Zuckerberg's Meta To Team Up With...  Mark Zuckerberg has revealed the key factors b...
# Meta exec Nick Clegg on AI: "I definitely think...  AI must be regulated, though companies can't w...
#
#                                                                                                   url  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  https://www.cnblogs.com/huggingface/p/17578351...
# Daily Hacker News for 2023-07-23                    https://www.daemonology.net/hn-daily/2023-07-2...
# How Meta’s Llama 2 Shifts Marketing’s Relations...  https://www.cmswire.com/digital-experience/how...
# Llama2.c: inference llama 2 in one file of pure...      https://news.ycombinator.com/item?id=36838051
# Alibaba's cloud unit brings Meta's AI model Lla...  https://economictimes.indiatimes.com/tech/tech...
# 4 big analyst picks: Meta lands a buy rating on...              https://biztoc.com/x/df335770b748ec0c
# Meta Stock: Facebook Parent Beats Q2 Goals                      https://biztoc.com/x/a50f66afcc2cf2f2
# AWS Week in Review – Redshift+Forecast, CodeCat...  https://aws.amazon.com/blogs/aws/aws-week-in-r...
# Alibaba Cloud to Support Meta AI Model for Chin...  https://www.investopedia.com/alibaba-cloud-to-...
# Unsupervised Learning NO. 391                                         http://danielmiessler.com/p/391
# Will Biden’s Meetings with A.I. Companies Make ...  https://www.newyorker.com/news/daily-comment/w...
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...  https://www.moneycontrol.com/news/world/alibab...
# This Week In Rust: This Week in Rust 505            https://this-week-in-rust.org/blog/2023/07/26/...
# Running Language Models – Deploy Llama2 7b on A...  https://blogs.sap.com/2023/07/28/running-langu...
# The Future of Programming: AI and Interface-Ori...  https://medium.com/javascript-scene/the-future...
# gentopia added to PyPI                                             https://pypi.org/project/gentopia/
# LLaMA2 Chat 70B outperformed ChatGPT                         https://tatsu-lab.github.io/alpaca_eval/
# Meta Platforms Stock Gets Upgraded Going Into E...              https://biztoc.com/x/ec1874bda26f4684
# 8 Ways to Try Llama 2 from Meta for Free            https://www.ilovefreesoftware.com/24/featured/...
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...  https://blogs.sap.com/2023/07/25/llama2-testin...
# Simplify your LLM Chatbot Demos with SAP BTP an...  https://blogs.sap.com/2023/07/23/simplify-your...
# Show HN: Goat-7B LLM, a new SOTA among the open...  https://huggingface.co/GOAT-AI/GOAT-7B-Communi...
# Llama We Doing This Again?                          https://www.lesswrong.com/posts/rhdAAFLgLBHLtG...
# A comprehensive guide to running Llama 2 locally         https://replicate.com/blog/run-llama-locally
# The Unprecedented Surge of AI by Big Tech           https://web-strategist.com/blog/2023/07/22/the...
# A Silent New AI Bombshell Launch Nobody Saw Coming              https://biztoc.com/x/0197f9ca1ccb69aa
# What is LLama2? : Dive into Meta AI’s Newest Op...              https://biztoc.com/x/b7773071a88fdd0b
# Meta reports Q2 revenue up 11% YoY to $32B, net...              https://biztoc.com/x/4ae441db4bdc6255
# Meta plans retention 'hooks' for Threads as mor...              https://biztoc.com/x/a969dc15002b9bda
# Llama2.c: inference llama 2 in one file of pure C                https://github.com/karpathy/llama2.c
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                 https://www.cnblogs.com/ms27946/p/llama-2-open...
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...              https://biztoc.com/x/7e734ee2146192e9
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...              https://biztoc.com/x/c506a47ce15da0b4
# Google, Microsoft, Amazon, Meta Pledge to Make ...              https://biztoc.com/x/71c34e7f0cfe0dd0
# Facebook parent Meta sees advertising jump, top...              https://biztoc.com/x/166d95a20fc82190
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2                                       https://llmboxing.com
# Alibaba to support Meta’s AI model Llama - report   https://cointelegraph.com/news/alibaba-to-supp...
# Google versus Microsoft versus Meta - Warum der...  https://www.focus.de/finanzen/boerse/aktien/go...
# Generative AI set to infuse $450B into enterpri...  https://cryptoslate.com/generative-ai-set-to-i...
# Meta’s Llama AI Model Now Accessible to Alibaba...              https://biztoc.com/x/f70a5ddcf0a1128f
# Meta Platforms Q2 Earnings Highlights: Revenue ...              https://biztoc.com/x/9662fd00aad0e567
# Facing more nimble rivals, OpenAI won’t bend … yet              https://biztoc.com/x/63683289148ba3c0
# What Led Mark Zuckerberg's Meta To Team Up With...              https://biztoc.com/x/d34e8148dc408324
# Meta exec Nick Clegg on AI: "I definitely think...              https://biztoc.com/x/d9e4558a7dcd83ee
#
#                                                                                            urlToImage  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...                                               None
# Daily Hacker News for 2023-07-23                                                                 None
# How Meta’s Llama 2 Shifts Marketing’s Relations...  https://www.cmswire.com/-/media/8be51baf377a40...
# Llama2.c: inference llama 2 in one file of pure...                                               None
# Alibaba's cloud unit brings Meta's AI model Lla...  https://img.etimg.com/thumb/msid-102126946,wid...
# 4 big analyst picks: Meta lands a buy rating on...     https://c.biztoc.com/p/df335770b748ec0c/s.webp
# Meta Stock: Facebook Parent Beats Q2 Goals            https://c.biztoc.com/p/a50f66afcc2cf2f2/og.webp
# AWS Week in Review – Redshift+Forecast, CodeCat...  https://d2908q01vomqb2.cloudfront.net/da4b9237...
# Alibaba Cloud to Support Meta AI Model for Chin...  https://www.investopedia.com/thmb/4DQiJTAZpSXt...
# Unsupervised Learning NO. 391                       https://beehiiv-images-production.s3.amazonaws...
# Will Biden’s Meetings with A.I. Companies Make ...  https://media.newyorker.com/photos/64bee5ef7a7...
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...  https://images.moneycontrol.com/static-mcnews/...
# This Week In Rust: This Week in Rust 505                                                         None
# Running Language Models – Deploy Llama2 7b on A...                                               None
# The Future of Programming: AI and Interface-Ori...  https://miro.medium.com/v2/resize:fit:1200/1*k...
# gentopia added to PyPI                              https://pypi.org/static/images/twitter.abaf4b1...
# LLaMA2 Chat 70B outperformed ChatGPT                                                             None
# Meta Platforms Stock Gets Upgraded Going Into E...     https://c.biztoc.com/p/ec1874bda26f4684/s.webp
# 8 Ways to Try Llama 2 from Meta for Free            https://www.ilovefreesoftware.com/wp-content/u...
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...                                               None
# Simplify your LLM Chatbot Demos with SAP BTP an...                                               None
# Show HN: Goat-7B LLM, a new SOTA among the open...  https://cdn-thumbnails.huggingface.co/social-t...
# Llama We Doing This Again?                          https://substackcdn.com/image/fetch/w_1456,c_l...
# A comprehensive guide to running Llama 2 locally    https://replicate.com/static/blog/run-llama-lo...
# The Unprecedented Surge of AI by Big Tech           https://web-strategist.com/blog/wp-content/upl...
# A Silent New AI Bombshell Launch Nobody Saw Coming     https://c.biztoc.com/p/0197f9ca1ccb69aa/s.webp
# What is LLama2? : Dive into Meta AI’s Newest Op...     https://c.biztoc.com/p/b7773071a88fdd0b/s.webp
# Meta reports Q2 revenue up 11% YoY to $32B, net...     https://c.biztoc.com/p/4ae441db4bdc6255/s.webp
# Meta plans retention 'hooks' for Threads as mor...     https://c.biztoc.com/p/a969dc15002b9bda/s.webp
# Llama2.c: inference llama 2 in one file of pure C   https://opengraph.githubassets.com/851b26341ff...
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                                                              None
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...     https://c.biztoc.com/p/7e734ee2146192e9/s.webp
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...     https://c.biztoc.com/p/c506a47ce15da0b4/s.webp
# Google, Microsoft, Amazon, Meta Pledge to Make ...    https://c.biztoc.com/p/71c34e7f0cfe0dd0/og.webp
# Facebook parent Meta sees advertising jump, top...     https://c.biztoc.com/p/166d95a20fc82190/s.webp
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2           https://llmboxing.com/images/stats-3423d0bf504...
# Alibaba to support Meta’s AI model Llama - report   https://images.cointelegraph.com/images/1200_a...
# Google versus Microsoft versus Meta - Warum der...  https://p6.focus.de/img/fotos/id_199901337/ki....
# Generative AI set to infuse $450B into enterpri...  https://cryptoslate.com/wp-content/uploads/202...
# Meta’s Llama AI Model Now Accessible to Alibaba...     https://c.biztoc.com/p/f70a5ddcf0a1128f/s.webp
# Meta Platforms Q2 Earnings Highlights: Revenue ...     https://c.biztoc.com/p/9662fd00aad0e567/s.webp
# Facing more nimble rivals, OpenAI won’t bend … yet     https://c.biztoc.com/p/63683289148ba3c0/s.webp
# What Led Mark Zuckerberg's Meta To Team Up With...     https://c.biztoc.com/p/d34e8148dc408324/s.webp
# Meta exec Nick Clegg on AI: "I definitely think...     https://c.biztoc.com/p/d9e4558a7dcd83ee/s.webp
#
#                                                              publishedAt  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  2023-07-24T12:59:00Z
# Daily Hacker News for 2023-07-23                    2023-07-24T00:00:00Z
# How Meta’s Llama 2 Shifts Marketing’s Relations...  2023-07-27T11:02:32Z
# Llama2.c: inference llama 2 in one file of pure...  2023-07-25T05:47:01Z
# Alibaba's cloud unit brings Meta's AI model Lla...  2023-07-26T05:31:09Z
# 4 big analyst picks: Meta lands a buy rating on...  2023-07-26T15:30:08Z
# Meta Stock: Facebook Parent Beats Q2 Goals          2023-07-27T17:06:13Z
# AWS Week in Review – Redshift+Forecast, CodeCat...  2023-07-24T22:58:56Z
# Alibaba Cloud to Support Meta AI Model for Chin...  2023-07-26T13:55:09Z
# Unsupervised Learning NO. 391                       2023-07-24T16:53:27Z
# Will Biden’s Meetings with A.I. Companies Make ...  2023-07-24T23:05:00Z
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...  2023-07-26T05:40:22Z
# This Week In Rust: This Week in Rust 505            2023-07-26T04:00:00Z
# Running Language Models – Deploy Llama2 7b on A...  2023-07-28T12:52:37Z
# The Future of Programming: AI and Interface-Ori...  2023-07-24T18:59:09Z
# gentopia added to PyPI                              2023-07-27T06:29:21Z
# LLaMA2 Chat 70B outperformed ChatGPT                2023-07-27T15:44:10Z
# Meta Platforms Stock Gets Upgraded Going Into E...  2023-07-25T14:40:04Z
# 8 Ways to Try Llama 2 from Meta for Free            2023-07-24T17:00:57Z
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...  2023-07-25T13:55:36Z
# Simplify your LLM Chatbot Demos with SAP BTP an...  2023-07-23T14:18:35Z
# Show HN: Goat-7B LLM, a new SOTA among the open...  2023-07-25T10:33:51Z
# Llama We Doing This Again?                          2023-07-26T13:00:09Z
# A comprehensive guide to running Llama 2 locally    2023-07-25T16:58:42Z
# The Unprecedented Surge of AI by Big Tech           2023-07-22T12:25:20Z
# A Silent New AI Bombshell Launch Nobody Saw Coming  2023-07-22T10:04:05Z
# What is LLama2? : Dive into Meta AI’s Newest Op...  2023-07-27T00:44:19Z
# Meta reports Q2 revenue up 11% YoY to $32B, net...  2023-07-26T20:22:06Z
# Meta plans retention 'hooks' for Threads as mor...  2023-07-28T02:36:06Z
# Llama2.c: inference llama 2 in one file of pure C   2023-07-23T18:13:54Z
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                 2023-07-27T15:15:00Z
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...  2023-07-26T20:32:15Z
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...  2023-07-26T20:32:17Z
# Google, Microsoft, Amazon, Meta Pledge to Make ...  2023-07-22T02:50:05Z
# Facebook parent Meta sees advertising jump, top...  2023-07-26T22:10:09Z
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2           2023-07-25T15:11:32Z
# Alibaba to support Meta’s AI model Llama - report   2023-07-26T09:50:59Z
# Google versus Microsoft versus Meta - Warum der...  2023-07-24T06:48:36Z
# Generative AI set to infuse $450B into enterpri...  2023-07-27T15:45:56Z
# Meta’s Llama AI Model Now Accessible to Alibaba...  2023-07-26T14:32:15Z
# Meta Platforms Q2 Earnings Highlights: Revenue ...  2023-07-26T21:06:28Z
# Facing more nimble rivals, OpenAI won’t bend … yet  2023-07-26T16:32:03Z
# What Led Mark Zuckerberg's Meta To Team Up With...  2023-07-27T05:18:04Z
# Meta exec Nick Clegg on AI: "I definitely think...  2023-07-25T19:20:06Z
#
#                                                                                               content
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  Hugging Face Hugging News Hugging News \r\n: \...
# Daily Hacker News for 2023-07-23                    The 10 highest-rated articles on\r\nHacker New...
# How Meta’s Llama 2 Shifts Marketing’s Relations...  The Gist\r\n<ul><li>Llama 2 launch. Meta's Lla...
# Llama2.c: inference llama 2 in one file of pure...  I got the strangest output from your first lin...
# Alibaba's cloud unit brings Meta's AI model Lla...  Alibaba's cloud computing division said it has...
# 4 big analyst picks: Meta lands a buy rating on...  Here is your Pro Recap of the biggest analyst ...
# Meta Stock: Facebook Parent Beats Q2 Goals          , parent company of Facebook, Instagram and Wh...
# AWS Week in Review – Redshift+Forecast, CodeCat...  Summer is in full swing here in Seattle and we...
# Alibaba Cloud to Support Meta AI Model for Chin...  The cloud arm of Alibaba Group (BABA) said Wed...
# Unsupervised Learning NO. 391                       Unsupervised Learning is a Security, AI, and M...
# Will Biden’s Meetings with A.I. Companies Make ...  On Friday, the Biden Administration announced ...
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...  Alibaba's cloud computing division said it has...
# This Week In Rust: This Week in Rust 505            Hello and welcome to another issue of This Wee...
# Running Language Models – Deploy Llama2 7b on A...  With the rapid release of new language models,...
# The Future of Programming: AI and Interface-Ori...  AI language models, such as ChatGPT and Claude...
# gentopia added to PyPI                              The Collective Growth of Intelligent Agents.\r...
# LLaMA2 Chat 70B outperformed ChatGPT                About AlpacaEval\r\nAlpacaEval\r\n an LLM-base...
# Meta Platforms Stock Gets Upgraded Going Into E...  Meta Platforms Inc META shares are trading hig...
# 8 Ways to Try Llama 2 from Meta for Free            Llama2 has shaken LLM world by its extra ordin...
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...  NOTE: The views and opinions expressed in this...
# Simplify your LLM Chatbot Demos with SAP BTP an...  NOTE: The views and opinions expressed in this...
# Show HN: Goat-7B LLM, a new SOTA among the open...  GOAT-7B-Community model\r\nGOAT-7B-Community m...
# Llama We Doing This Again?                          Ive finally had an opportunity to gather the a...
# A comprehensive guide to running Llama 2 locally    Weve been talking a lot about how to run and f...
# The Unprecedented Surge of AI by Big Tech           Eight Significant AI Moves from Tech Giants in...
# A Silent New AI Bombshell Launch Nobody Saw Coming  A Silent New AI Bombshell Launch Nobody Saw Co...
# What is LLama2? : Dive into Meta AI’s Newest Op...  Meta AI and Microsoft have come together to la...
# Meta reports Q2 revenue up 11% YoY to $32B, net...  MENLO PARK, Calif., July 26, 2023 /PRNewswire/...
# Meta plans retention 'hooks' for Threads as mor...  Meta Platforms executives are heavily focused ...
# Llama2.c: inference llama 2 in one file of pure C   llama2.c\r\nHave you ever wanted to inference ...
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                 LLM Llama 2\r\nChatGPT3.5DeepLCopilot X\r\nLla...
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...  Social network operator Meta Platforms (NASDAQ...
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...  Updated at 4:24 pm EDTMeta Platforms (META) - ...
# Google, Microsoft, Amazon, Meta Pledge to Make ...  The White House has secured "voluntary commitm...
# Facebook parent Meta sees advertising jump, top...  Meta Platforms on Wednesday reported a quick r...
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2           Llama2\r\n has taken the world by storm. Many ...
# Alibaba to support Meta’s AI model Llama - report   E-commerce group Alibaba will become the first...
# Google versus Microsoft versus Meta - Warum der...  In rasantem Tempo erobert künstliche Intellige...
# Generative AI set to infuse $450B into enterpri...  Generative Artificial Intelligence (AI) contin...
# Meta’s Llama AI Model Now Accessible to Alibaba...  CoinspeakerMetas Llama AI Model Now Accessible...
# Meta Platforms Q2 Earnings Highlights: Revenue ...  Technology company Meta Platforms META reporte...
# Facing more nimble rivals, OpenAI won’t bend … yet  The ScoopCustomers have asked to run OpenAI mo...
# What Led Mark Zuckerberg's Meta To Team Up With...  Mark Zuckerberg has revealed the key factors b...
# Meta exec Nick Clegg on AI: "I definitely think...  AI must be regulated, though companies can't w...

# %% [markdown]
# # Embedding做文章排序

# %%
import pandas as pd

df = pd.read_csv('last_documents.csv', index_col=0)
df.head(3)
# Out:
#                                                                                      source  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...      {'id': None, 'name': 'Cnblogs.com'}
# Daily Hacker News for 2023-07-23                    {'id': None, 'name': 'Daemonology.net'}
# How Meta’s Llama 2 Shifts Marketing’s Relations...          {'id': None, 'name': 'CMSWire'}
#
#                                                                             author  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...                     HuggingFace
# Daily Hacker News for 2023-07-23                                               NaN
# How Meta’s Llama 2 Shifts Marketing’s Relations...  pr@cmswire.com (Pierre DeBois)
#
#                                                                                                 title  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  Hugging News #0724: Llama 2 登陆 Hugging Face、AI...
# Daily Hacker News for 2023-07-23                                     Daily Hacker News for 2023-07-23
# How Meta’s Llama 2 Shifts Marketing’s Relations...  How Meta’s Llama 2 Shifts Marketing’s Relation...
#
#                                                                                           description  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  每一周，我们的同事都会向社区的成员们发布一些关于 Hugging Face 相关的更新，包括...
# Daily Hacker News for 2023-07-23                    The 10 highest-rated articles on\nHacker News\...
# How Meta’s Llama 2 Shifts Marketing’s Relations...  Learn how Meta’s Llama 2 is changing the marke...
#
#                                                                                                   url  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  https://www.cnblogs.com/huggingface/p/17578351...
# Daily Hacker News for 2023-07-23                    https://www.daemonology.net/hn-daily/2023-07-2...
# How Meta’s Llama 2 Shifts Marketing’s Relations...  https://www.cmswire.com/digital-experience/how...
#
#                                                                                            urlToImage  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...                                                NaN
# Daily Hacker News for 2023-07-23                                                                  NaN
# How Meta’s Llama 2 Shifts Marketing’s Relations...  https://www.cmswire.com/-/media/8be51baf377a40...
#
#                                                              publishedAt  \
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  2023-07-24T12:59:00Z
# Daily Hacker News for 2023-07-23                    2023-07-24T00:00:00Z
# How Meta’s Llama 2 Shifts Marketing’s Relations...  2023-07-27T11:02:32Z
#
#                                                                                               content
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  Hugging Face Hugging News Hugging News \r\n: \...
# Daily Hacker News for 2023-07-23                    The 10 highest-rated articles on\r\nHacker New...
# How Meta’s Llama 2 Shifts Marketing’s Relations...  The Gist\r\n<ul><li>Llama 2 launch. Meta's Lla...

# %%
from sentence_transformers import SentenceTransformer

instruction = "为这个句子生成表示以用于检索相关文章："
instruction_en = "Represent this sentence for searching relevant passages:"
queries = ["LLaMA RLHF"]
passages = [
    f"{article['title']} {article['description']} {article['content']}"
        for _, article in df.iterrows()
]

model = SentenceTransformer('BAAI/bge-large-en')
q_embeddings = model.encode([instruction_en+q for q in queries], normalize_embeddings=True)
p_embeddings = model.encode(passages, normalize_embeddings=True)
scores = q_embeddings @ p_embeddings.T
scores
# Out:
# array([[0.75337267, 0.6653036 , 0.72978985, 0.7472973 , 0.74269295,
#         0.6478652 , 0.65310436, 0.6958818 , 0.6909492 , 0.6593058 ,
#         0.642282  , 0.75479937, 0.65342087, 0.7440892 , 0.64307153,
#         0.6774725 , 0.7743534 , 0.7009691 , 0.7353648 , 0.7438247 ,
#         0.68389887, 0.7672374 , 0.74533165, 0.7418338 , 0.63542855,
#         0.7460848 , 0.7522627 , 0.6734979 , 0.6353735 , 0.7735085 ,
#         0.758535  , 0.63516665, 0.65505517, 0.65303767, 0.6466215 ,
#         0.75210625, 0.74482125, 0.666496  , 0.6433321 , 0.7228894 ,
#         0.64142954, 0.612141  , 0.7044281 , 0.6454203 ]], dtype=float32)

# %%
xdf = df.copy()
xdf["score"] = scores[0]
xdf.sort_values(by='score', ascending=False)[['title', 'description', 'score']]
# Out:
#                                                                                                 title  \
# LLaMA2 Chat 70B outperformed ChatGPT                             LLaMA2 Chat 70B outperformed ChatGPT
# Llama2.c: inference llama 2 in one file of pure C   Llama2.c: inference llama 2 in one file of pure C
# Show HN: Goat-7B LLM, a new SOTA among the open...  Show HN: Goat-7B LLM, a new SOTA among the ope...
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                               Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...  Alibaba#39;s cloud unit brings Meta#39;s AI mo...
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  Hugging News #0724: Llama 2 登陆 Hugging Face、AI...
# What is LLama2? : Dive into Meta AI’s Newest Op...  What is LLama2? : Dive into Meta AI’s Newest O...
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2                   Show HN: LLM Boxing – GPT 3.5 vs. Llama 2
# Llama2.c: inference llama 2 in one file of pure...  Llama2.c: inference llama 2 in one file of pur...
# A Silent New AI Bombshell Launch Nobody Saw Coming  A Silent New AI Bombshell Launch Nobody Saw Co...
# Llama We Doing This Again?                                                 Llama We Doing This Again?
# Alibaba to support Meta’s AI model Llama - report   Alibaba to support Meta’s AI model Llama - report
# Running Language Models – Deploy Llama2 7b on A...  Running Language Models – Deploy Llama2 7b on ...
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...  LLAMA2: Testing a Tiny LLM with Hugging Face &...
# Alibaba's cloud unit brings Meta's AI model Lla...  Alibaba's cloud unit brings Meta's AI model Ll...
# A comprehensive guide to running Llama 2 locally     A comprehensive guide to running Llama 2 locally
# 8 Ways to Try Llama 2 from Meta for Free                     8 Ways to Try Llama 2 from Meta for Free
# How Meta’s Llama 2 Shifts Marketing’s Relations...  How Meta’s Llama 2 Shifts Marketing’s Relation...
# Meta’s Llama AI Model Now Accessible to Alibaba...  Meta’s Llama AI Model Now Accessible to Alibab...
# What Led Mark Zuckerberg's Meta To Team Up With...  What Led Mark Zuckerberg's Meta To Team Up Wit...
# Meta Platforms Stock Gets Upgraded Going Into E...  Meta Platforms Stock Gets Upgraded Going Into ...
# AWS Week in Review – Redshift+Forecast, CodeCat...  AWS Week in Review – Redshift+Forecast, CodeCa...
# Alibaba Cloud to Support Meta AI Model for Chin...  Alibaba Cloud to Support Meta AI Model for Chi...
# Simplify your LLM Chatbot Demos with SAP BTP an...  Simplify your LLM Chatbot Demos with SAP BTP a...
# gentopia added to PyPI                                                         gentopia added to PyPI
# Meta reports Q2 revenue up 11% YoY to $32B, net...  Meta reports Q2 revenue up 11% YoY to $32B, ne...
# Google versus Microsoft versus Meta - Warum der...  Google versus Microsoft versus Meta - Warum de...
# Daily Hacker News for 2023-07-23                                     Daily Hacker News for 2023-07-23
# Unsupervised Learning NO. 391                                           Unsupervised Learning NO. 391
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...  Meta Leaps As Zuckerberg Touts AI Pipeline In ...
# This Week In Rust: This Week in Rust 505                     This Week In Rust: This Week in Rust 505
# Meta Stock: Facebook Parent Beats Q2 Goals                 Meta Stock: Facebook Parent Beats Q2 Goals
# Google, Microsoft, Amazon, Meta Pledge to Make ...  Google, Microsoft, Amazon, Meta Pledge to Make...
# 4 big analyst picks: Meta lands a buy rating on...  4 big analyst picks: Meta lands a buy rating o...
# Facebook parent Meta sees advertising jump, top...  Facebook parent Meta sees advertising jump, to...
# Meta exec Nick Clegg on AI: "I definitely think...  Meta exec Nick Clegg on AI: "I definitely thin...
# Generative AI set to infuse $450B into enterpri...  Generative AI set to infuse $450B into enterpr...
# The Future of Programming: AI and Interface-Ori...  The Future of Programming: AI and Interface-Or...
# Will Biden’s Meetings with A.I. Companies Make ...  Will Biden’s Meetings with A.I. Companies Make...
# Meta Platforms Q2 Earnings Highlights: Revenue ...  Meta Platforms Q2 Earnings Highlights: Revenue...
# The Unprecedented Surge of AI by Big Tech                   The Unprecedented Surge of AI by Big Tech
# Meta plans retention 'hooks' for Threads as mor...  Meta plans retention 'hooks' for Threads as mo...
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...  Meta (NASDAQ:META) Surprises With Q2 Sales, St...
# Facing more nimble rivals, OpenAI won’t bend … yet  Facing more nimble rivals, OpenAI won’t bend …...
#
#                                                                                           description  \
# LLaMA2 Chat 70B outperformed ChatGPT                                                         Comments
# Llama2.c: inference llama 2 in one file of pure C   Inference Llama 2 in one file of pure C. Contr...
# Show HN: Goat-7B LLM, a new SOTA among the open...  New research results around LLM 'alignment', d...
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                 # Llama 2：开放式基础和微调聊天模型 ## 写在前头 因为最近一直在使用 LLM 工...
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...  Meta released Llama2, a commercial version of ...
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  每一周，我们的同事都会向社区的成员们发布一些关于 Hugging Face 相关的更新，包括...
# What is LLama2? : Dive into Meta AI’s Newest Op...  Meta AI and Microsoft have come together to la...
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2           Article URL: https://llmboxing.com\nComments U...
# Llama2.c: inference llama 2 in one file of pure...                                                NaN
# A Silent New AI Bombshell Launch Nobody Saw Coming  A Silent New AI Bombshell Launch Nobody Saw Co...
# Llama We Doing This Again?                          Published on July 26, 2023 1:00 PM GMTI’ve fin...
# Alibaba to support Meta’s AI model Llama - report   Alibaba Cloud is reportedly set to integrate M...
# Running Language Models – Deploy Llama2 7b on A...  With the rapid release of new language models,...
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...  NOTE: The views and opinions expressed in this...
# Alibaba's cloud unit brings Meta's AI model Lla...  Alibaba's cloud computing division said it has...
# A comprehensive guide to running Llama 2 locally    Article URL: https://replicate.com/blog/run-ll...
# 8 Ways to Try Llama 2 from Meta for Free            Here is a list of free websites where you can ...
# How Meta’s Llama 2 Shifts Marketing’s Relations...  Learn how Meta’s Llama 2 is changing the marke...
# Meta’s Llama AI Model Now Accessible to Alibaba...  Coinspeaker Meta’s Llama AI Model Now Accessib...
# What Led Mark Zuckerberg's Meta To Team Up With...  Mark Zuckerberg has revealed the key factors b...
# Meta Platforms Stock Gets Upgraded Going Into E...  Meta Platforms Inc META shares are trading hig...
# AWS Week in Review – Redshift+Forecast, CodeCat...  Summer is in full swing here in Seattle and we...
# Alibaba Cloud to Support Meta AI Model for Chin...  ADRs of Alibaba and Meta shares rose after the...
# Simplify your LLM Chatbot Demos with SAP BTP an...  NOTE: The views and opinions expressed in this...
# gentopia added to PyPI                              Gentopia provides extensive utilities to assem...
# Meta reports Q2 revenue up 11% YoY to $32B, net...  MENLO PARK, Calif., July 26, 2023 /PRNewswire/...
# Google versus Microsoft versus Meta - Warum der...  In rasantem Tempo erobert künstliche Intellige...
# Daily Hacker News for 2023-07-23                    The 10 highest-rated articles on\nHacker News\...
# Unsupervised Learning NO. 391                       AI Manipulation Defenders, .MIL Leak, and the ...
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...  Updated at 4:24 pm EDT Meta Platforms (META) -...
# This Week In Rust: This Week in Rust 505            Hello and welcome to another issue of This Wee...
# Meta Stock: Facebook Parent Beats Q2 Goals          parent company of Facebook, Instagram and What...
# Google, Microsoft, Amazon, Meta Pledge to Make ...  The White House has secured "voluntary commitm...
# 4 big analyst picks: Meta lands a buy rating on...  Here is your Pro Recap of the biggest analyst ...
# Facebook parent Meta sees advertising jump, top...  Meta Platforms on Wednesday reported a quick r...
# Meta exec Nick Clegg on AI: "I definitely think...  AI must be regulated, though companies can't w...
# Generative AI set to infuse $450B into enterpri...  Generative Artificial Intelligence (AI) contin...
# The Future of Programming: AI and Interface-Ori...  AI language models, such as ChatGPT and Claude...
# Will Biden’s Meetings with A.I. Companies Make ...  Voluntary commitments from the likes of OpenAI...
# Meta Platforms Q2 Earnings Highlights: Revenue ...  Technology company Meta Platforms META reporte...
# The Unprecedented Surge of AI by Big Tech           Eight Significant AI Moves from Tech Giants in...
# Meta plans retention 'hooks' for Threads as mor...  Meta Platforms executives are heavily focused ...
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...  Social network operator Meta Platforms (NASDAQ...
# Facing more nimble rivals, OpenAI won’t bend … yet  The Scoop Customers have asked to run OpenAI m...
#
#                                                        score
# LLaMA2 Chat 70B outperformed ChatGPT                0.774353
# Llama2.c: inference llama 2 in one file of pure C   0.773508
# Show HN: Goat-7B LLM, a new SOTA among the open...  0.767237
# Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕                 0.758535
# Alibaba#39;s cloud unit brings Meta#39;s AI mod...  0.754799
# Hugging News #0724: Llama 2 登陆 Hugging Face、AI ...  0.753373
# What is LLama2? : Dive into Meta AI’s Newest Op...  0.752263
# Show HN: LLM Boxing – GPT 3.5 vs. Llama 2           0.752106
# Llama2.c: inference llama 2 in one file of pure...  0.747297
# A Silent New AI Bombshell Launch Nobody Saw Coming  0.746085
# Llama We Doing This Again?                          0.745332
# Alibaba to support Meta’s AI model Llama - report   0.744821
# Running Language Models – Deploy Llama2 7b on A...  0.744089
# LLAMA2: Testing a Tiny LLM with Hugging Face & ...  0.743825
# Alibaba's cloud unit brings Meta's AI model Lla...  0.742693
# A comprehensive guide to running Llama 2 locally    0.741834
# 8 Ways to Try Llama 2 from Meta for Free            0.735365
# How Meta’s Llama 2 Shifts Marketing’s Relations...  0.729790
# Meta’s Llama AI Model Now Accessible to Alibaba...  0.722889
# What Led Mark Zuckerberg's Meta To Team Up With...  0.704428
# Meta Platforms Stock Gets Upgraded Going Into E...  0.700969
# AWS Week in Review – Redshift+Forecast, CodeCat...  0.695882
# Alibaba Cloud to Support Meta AI Model for Chin...  0.690949
# Simplify your LLM Chatbot Demos with SAP BTP an...  0.683899
# gentopia added to PyPI                              0.677472
# Meta reports Q2 revenue up 11% YoY to $32B, net...  0.673498
# Google versus Microsoft versus Meta - Warum der...  0.666496
# Daily Hacker News for 2023-07-23                    0.665304
# Unsupervised Learning NO. 391                       0.659306
# Meta Leaps As Zuckerberg Touts AI Pipeline In S...  0.655055
# This Week In Rust: This Week in Rust 505            0.653421
# Meta Stock: Facebook Parent Beats Q2 Goals          0.653104
# Google, Microsoft, Amazon, Meta Pledge to Make ...  0.653038
# 4 big analyst picks: Meta lands a buy rating on...  0.647865
# Facebook parent Meta sees advertising jump, top...  0.646622
# Meta exec Nick Clegg on AI: "I definitely think...  0.645420
# Generative AI set to infuse $450B into enterpri...  0.643332
# The Future of Programming: AI and Interface-Ori...  0.643072
# Will Biden’s Meetings with A.I. Companies Make ...  0.642282
# Meta Platforms Q2 Earnings Highlights: Revenue ...  0.641430
# The Unprecedented Surge of AI by Big Tech           0.635429
# Meta plans retention 'hooks' for Threads as mor...  0.635373
# Meta (NASDAQ:META) Surprises With Q2 Sales, Sto...  0.635167
# Facing more nimble rivals, OpenAI won’t bend … yet  0.612141

# %%
from langchain.embeddings import HuggingFaceEmbeddings, HuggingFaceInstructEmbeddings

model = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-xl", model_kwargs={"device": "cuda"})

def embeddings(inputs):
    return model.embed_documents(inputs)
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
article_embeddings = embeddings(
    [
        f"{article['title']} {article['description']} {article['content']}"
        for _, article in df.iterrows()
    ]
)

# %% [markdown]
# # Re-rank

# %%
hypothetical_answer = "There have been rumors circulating about LLaMA2 making a major announcement at their upcoming event. Some speculate that NAME, the CEO of LLaMA2, will unveil a groundbreaking new technology. However, nothing has been confirmed yet and we'll have to wait for the event to find out more."

hypothetical_answer_embedding = embeddings(hypothetical_answer)[0]

# %%
import numpy as np

# Calculate cosine similarity
cosine_similarities = []
for article_embedding in article_embeddings:
    cosine_similarities.append(np.dot(hypothetical_answer_embedding, article_embedding))

np.max(cosine_similarities)
# Out:
# 0.5697349326708971

# %%
df['similarity'] = cosine_similarities

xdf = df.sort_values(by='similarity', ascending=False).reset_index()
for i, row in xdf.head(10).iterrows():
    print(f"[{i+1}] Title:", row['title'])
    print("Description:", row["description"])
    print("Content:", row["content"])
    # print("Link:", row["url"])
    # print("Score:", row["similarity"])
    print(" ")
# Out:
# [1/10] Title: Llama2 论文中译版——开放式基础和微调聊天模型 - 沉睡的木木夕
# Description: # Llama 2：开放式基础和微调聊天模型 ## 写在前头 因为最近一直在使用 LLM 工具，所以在学习 [Llama 2：开放式基础和微调聊天模型](https://ai.meta.com/research/publications/llama-2-open-foundation-and-fin
# Content: LLM Llama 2
# ChatGPT3.5DeepLCopilot X
# Llama 2LLMs 70 700 LLMs Llama 2-Chat Llama 2-Chat LLMs
# Llama 2-Chat 4k 95% 1% 2% 3.4.2
# GPT- 4 Llama 2-Chat GPT-4 /+ GPT-4
# 1
# LLMs
# LLMs Auto-regressive t… [+12961 chars]
#
# [2/10] Title: This Week In Rust: This Week in Rust 505
# Description: Hello and welcome to another issue of This Week in Rust!
# Rust is a programming language empowering everyone to build reliable and efficient software.
# This is a weekly summary of its progress and community.
# Want something mentioned? Tag us at @ThisWeekInRust o…
# Content: Hello and welcome to another issue of This Week in Rust!
# Rust is a programming language empowering everyone to build reliable and efficient software.
# This is a weekly summary of its progress and co… [+11470 chars]
#
# [3/10] Title: LLaMA2 Chat 70B outperformed ChatGPT
# Description: Comments
# Content: About AlpacaEval
# AlpacaEval
#  an LLM-based automatic evaluation that is fast, cheap, and reliable.
#  It is based on the
#  AlpacaFarm
#  evaluation set,
#  which tests the ability of models to follow g… [+1962 chars]
#
# [4/10] Title: LLAMA2: Testing a Tiny LLM with Hugging Face & SAP BTP
# Description: NOTE: The views and opinions expressed in this blog are my own Meta have recently made available their  Llama2 Large Language Models (LLM) for free, for commercial usage.  https://ai.meta.com/llama/ Though they may lack the breadth and depth […]
# Content: NOTE: The views and opinions expressed in this blog are my own
# Meta have recently made available their  Llama2 Large Language Models (LLM) for free, for commercial usage.  https://ai.meta.com/llama/… [+4811 chars]
#
# [5/10] Title: A Silent New AI Bombshell Launch Nobody Saw Coming
# Description: A Silent New AI Bombshell Launch Nobody Saw Coming Meta’s pulling out the big guns. LLaMA 2, their shiny new AI, is now open-source. Free for anyone. And I mean anyone. Your grandma, your dog, even your weird neighbor who still uses a flip phone. Is it a nobl…
# Content: A Silent New AI Bombshell Launch Nobody Saw ComingMetas pulling out the big guns. LLaMA 2, their shiny new AI, is now open-source. Free for anyone. And I mean anyone. Your grandma, your dog, even you… [+228 chars]
#
# [6/10] Title: Show HN: Goat-7B LLM, a new SOTA among the open-source 7B models
# Description: New research results around LLM 'alignment', data filtering and model training.
#
# Comments URL: https://news.ycombinator.com/item?id=36860356
# Points: 2
# # Comments: 0
# Content: GOAT-7B-Community model
# GOAT-7B-Community model is supervised finetuned (SFT) version of LLaMA 2 developed by GOAT.AI lab on user-shared conversations from GoatChat app.
# Model description
# <ul><li>… [+1828 chars]
#
# [7/10] Title: Hugging News #0724: Llama 2 登陆 Hugging Face、AI 开源游戏竞赛获奖选手公布！ - HuggingFace
# Description: 每一周，我们的同事都会向社区的成员们发布一些关于 Hugging Face 相关的更新，包括我们的产品和平台更新、社区活动、学习资源和内容更新、开源库和模型更新等，我们将其称之为「Hugging News」。本期 Hugging News 有哪些有趣的消息，快来看看吧！  ## 重点内容 #
# Content: Hugging Face Hugging News Hugging News
# :
# Hugging Face
#  ERNIE ViLG () Stable Diffusion v 2.1 ()
# #4:
#  Whisper
# Whisper
# Whisper OpenAI 2022
# "X"
# <ul><li> "X" Whisper </li><li>"X" LLM GPT-… [+682 chars]
#
# [8/10] Title: Show HN: LLM Boxing – GPT 3.5 vs. Llama 2
# Description: Article URL: https://llmboxing.com
# Comments URL: https://news.ycombinator.com/item?id=36863489
# Points: 1
# # Comments: 1
# Content: Llama2
#  has taken the world by storm. Many have
#  claimed performance similar to OpenAI's GPT-3.5. Let's put that to the test.
# Each round, pick the output you think is better. Each model has 5 hitp… [+57 chars]
#
# [9/10] Title: Llama2.c: inference llama 2 in one file of pure C | Hacker News
# Description: nan
# Content: I got the strangest output from your first link. It starts off sane enough, but then starts devolving with typos, then gibberish, then maybe foreign languages and some more technical/programmatic ter… [+5952 chars]
#
# [10/10] Title: Llama2.c: inference llama 2 in one file of pure C
# Description: Inference Llama 2 in one file of pure C. Contribute to karpathy/llama2.c development by creating an account on GitHub.
# Content: llama2.c
# Have you ever wanted to inference a baby Llama 2 model in pure C? No? Well, now you can!
# With this code you can train the Llama 2 LLM architecture from scratch in PyTorch, then save the we… [+5027 chars]
