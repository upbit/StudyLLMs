# %%
# !pip install langchain openai tiktoken chromadb pypdf sentence_transformers InstructorEmbedding faiss-cpu

# %% [markdown]
# # PDF

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader

root_dir = "D:/Papers"

# 加载目录下全部 PDF
# loader = DirectoryLoader(f'{root_dir}/', glob="./*.pdf", loader_cls=PyPDFLoader)
# documents = loader.load()

# 单个PDF
filename = "2201.11903_CoT"
loader = PyPDFLoader(f"{root_dir}/{filename}.pdf")
documents = loader.load()

# %% [markdown]
# # HTML

# %%
from langchain.document_loaders import BSHTMLLoader, DirectoryLoader

root_dir = "UE5.2_Docs\Animating Characters and Objects"
loader = DirectoryLoader(f'{root_dir}/', glob="./*.html", loader_cls=BSHTMLLoader, loader_kwargs={"open_encoding": 'utf-8'})

documents = loader.load()
documents[0]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts = text_splitter.split_documents(documents)

# %% [markdown]
# # Markdown - UE

# %%
import re
import logging
from typing import Dict, List, Union

from langchain.docstore.document import Document
from langchain.document_loaders.base import BaseLoader

logger = logging.getLogger(__name__)


class UEDocs_HTMLLoader(BaseLoader):
    """Loader that uses beautiful soup to parse Unreal HTML files."""

    def __init__(
        self,
        file_path: str,
        open_encoding: Union[str, None] = None,
        bs_kwargs: Union[dict, None] = None,
        get_text_separator: str = "",
    ) -> None:
        """Initialise with path, and optionally, file encoding to use, and any kwargs
        to pass to the BeautifulSoup object.

        Args:
            file_path: The path to the file to load.
            open_encoding: The encoding to use when opening the file.
            bs_kwargs: Any kwargs to pass to the BeautifulSoup object.
            get_text_separator: The separator to use when calling get_text on the soup.
        """
        try:
            import bs4  # noqa:F401
        except ImportError:
            raise ImportError(
                "beautifulsoup4 package not found, please install it with "
                "`pip install beautifulsoup4`"
            )
        try:
            import markdownify  # noqa:F401
        except ImportError:
            raise ImportError(
                "markdownify package not found, please install it with "
                "`pip install markdownify`"
            )

        self.file_path = file_path
        self.open_encoding = open_encoding
        if bs_kwargs is None:
            bs_kwargs = {"features": "lxml"}
        self.bs_kwargs = bs_kwargs
        self.get_text_separator = get_text_separator

    def load(self) -> List[Document]:
        """Load HTML document into document objects."""
        from bs4 import BeautifulSoup
        import markdownify

        with open(self.file_path, "r", encoding=self.open_encoding) as f:
            soup = BeautifulSoup(f, **self.bs_kwargs)

        content_div = soup.find('div', id='contentContainer')
        md = markdownify.markdownify(content_div.encode_contents(), heading_style='atx')

        cleaned_text = re.sub(r'^\s+', '', str(md)) # 去掉开头空白
        cleaned_text = re.sub(r'\n{2,}', r'\n\n', cleaned_text) # 限制连续换行
        cleaned_text = re.sub(r'\n +', r'\n', cleaned_text) # 去除行首空格
        cleaned_text = re.sub(r' +', r' ', cleaned_text) # 去除重复空格

        if soup.title:
            title = str(soup.title.string)
        else:
            title = ""

        metadata: Dict[str, Union[str, None]] = {
            "source": self.file_path,
            "title": title,
        }
        return [Document(page_content=cleaned_text, metadata=metadata)]

# loader = UEDocs_HTMLLoader('UE5.2_Docs\Animating Characters and Objects\index.html')
# documents = loader.load()
# documents[0]

# %%
from langchain.document_loaders import DirectoryLoader

root_dir = "UE5.2_Docs\Animating Characters and Objects"
loader = DirectoryLoader(f'{root_dir}/', glob="./*.html", loader_cls=UEDocs_HTMLLoader, loader_kwargs={"open_encoding": 'utf-8'})

documents = loader.load()
len(documents), documents[0]
# Out:
# D:\Software\oobabooga_windows\installer_files\env\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# (6,
#  Document(page_content="![](./../../Images/animating-characters-and-objects/BannerImage.png) \n\n# Animating Characters and Objects\n\n## Explore Unreal Engine's animation tools and editors for working with 2D and 3D characters and objects.\n\n\n\nOn this page\n\n\n* [Skeletal Mesh Animation](#skeletalmeshanimation)\n* [Sequencer](#sequencer)\n* [Control Rig](#controlrig)\n* [Paper 2D](#paper2d)\n\nYou can use **Unreal Engine**'s suite of powerful animation tools and editors to create character and object runtime animation systems, rendered cinematic content, and author new animation content directly in the engine.\n\n## Skeletal Mesh Animation\n\nWith the [Skeletal Mesh Animation System](../skeletal-mesh-animation-system-in-unreal-engine), you can create robust animation systems for characters and objects within Unreal Engine. After importing a skinned mesh object as a [Skeletal Mesh asset](../skeletal-mesh-assets-in-unreal-engine), you can manage its properties and build logic to run dynamic animation content using the [Animation Blueprint](../animation-blueprints-in-unreal-engine) visual scripting editor.\n\nFor more information about the using the **Skeletal Animation System** to animate characters and objects in unreal engine, see the following documentation:\n\n[![TopicImage.png]()\n\n\nSkeletal Mesh Animation System\n\n\nUnreal Engine's system for animation and controlling characters.](../skeletal-mesh-animation-system-in-unreal-engine)\n\n## Sequencer\n\nYou can use [Sequencer](../cinematics-and-movie-making-in-unreal-engine) to create and edit staged animation content for game cinematics or traditional animated filmmaking while taking advantage of Unreal Engine's animation and world rendering tools. When creating cinematic content using Sequencer, you can build custom character rigs, using [Control Rig](../control-rig-in-unreal-engine) to animate characters directly in your scene while simultaneously animating other characters, objects, cameras, and effects.\n\nFor more information about using **Sequencer** to create cinematic animations in Unreal Engine, see the following documentation:\n\n[![TopicImage.png]()\n\n\nCinematics and Sequencer\n\n\nSequencer is Unreal Engine's multi-track editor used for creating and previewing cinematic sequences in real time.](../cinematics-and-movie-making-in-unreal-engine)\n\n## Control Rig\n\nUsing the Skeletal Mesh Animation System, imported characters can run animations that have been created in external DCC software. However, using [Control Rig](../control-rig-in-unreal-engine), you can build dynamic animation rigs for characters and objects, enabling you to edit existing animations or create new animations within Unreal Engine. Using the [Control Rig blueprint graph](../control-rig-editor-in-unreal-engine) you can create dynamic rigs that can apply bone transforms to mesh skeletons. These animations can then be played in Sequencer or even baked as standalone assets that can be used in a runtime animation system.\n\nFor more information about using **Control Rig** to animate characters in Unreal Engine, see the following documentation:\n\n[![TopicImage.png]()\n\n\nControl Rig\n\n\nRig and Animate characters in real-time using Control Rig.](../control-rig-in-unreal-engine)\n\n## Paper 2D\n\nUsing Unreal Engine's 2D animation tool set, [Paper 2D](../paper-2d-in-unreal-engine), you can create traditional 2D characters or levels that are able to leverage the full capabilities of Unreal Engine's world rendering to create dynamic high-fidelity 2D and 2D / 3D hybrid projects. Paper 2D contains a suite of tools and editors that you can use to edit 2D textures, within the framework of Unreal Engine's modern light, world, and physics simulation.\n\nFor more information about creating traditional 2D and modern hybrid style projects using **Paper 2D** in Unreal Engine, see the following documentation:\n\n[![Paper2D_Topic.png]()\n\n\nPaper 2D\n\n\nPaper 2D is a sprite-based system for creatin ...

# %%
from langchain.text_splitter import MarkdownTextSplitter

text_splitter = MarkdownTextSplitter(chunk_size=2000, chunk_overlap=200)
texts = text_splitter.split_documents(documents)

# %% [markdown]
# # embeddings
#
# * 中文：**shibing624/text2vec-base-chinese** / **shibing624/text2vec-base-chinese-paraphrase** / **moka-ai/m3e-base**
# * 英文：**hkunlp/instructor-xl**l

# %%
len(texts), texts[0]
# Out:
# (62,
#  Document(page_content="![](./../../Images/animating-characters-and-objects/BannerImage.png) \n\n# Animating Characters and Objects\n\n## Explore Unreal Engine's animation tools and editors for working with 2D and 3D characters and objects.\n\n\n\nOn this page\n\n\n* [Skeletal Mesh Animation](#skeletalmeshanimation)\n* [Sequencer](#sequencer)\n* [Control Rig](#controlrig)\n* [Paper 2D](#paper2d)\n\nYou can use **Unreal Engine**'s suite of powerful animation tools and editors to create character and object runtime animation systems, rendered cinematic content, and author new animation content directly in the engine.\n\n## Skeletal Mesh Animation\n\nWith the [Skeletal Mesh Animation System](../skeletal-mesh-animation-system-in-unreal-engine), you can create robust animation systems for characters and objects within Unreal Engine. After importing a skinned mesh object as a [Skeletal Mesh asset](../skeletal-mesh-assets-in-unreal-engine), you can manage its properties and build logic to run dynamic animation content using the [Animation Blueprint](../animation-blueprints-in-unreal-engine) visual scripting editor.\n\nFor more information about the using the **Skeletal Animation System** to animate characters and objects in unreal engine, see the following documentation:\n\n[![TopicImage.png]()\n\n\nSkeletal Mesh Animation System\n\n\nUnreal Engine's system for animation and controlling characters.](../skeletal-mesh-animation-system-in-unreal-engine)", metadata={'source': 'UE5.2_Docs\\Animating Characters and Objects\\index.html', 'title': 'Animating Characters and Objects in Unreal Engine | Unreal Engine 5.2 Documentation'}))

# %%
from langchain.embeddings import HuggingFaceEmbeddings, HuggingFaceInstructEmbeddings

# 英文
embeddings = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-xl", model_kwargs={"device": "cuda"})

# 中文
# embeddings = HuggingFaceEmbeddings(model_name="shibing624/text2vec-base-chinese", model_kwargs={"device": "cuda"})
# embeddings = HuggingFaceEmbeddings(model_name="moka-ai/m3e-base", model_kwargs={"device": "cuda"})
# Out:
# D:\Software\oobabooga_windows\installer_files\env\lib\site-packages\InstructorEmbedding\instructor.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
from langchain.vectorstores import FAISS

# add
# db = FAISS.from_documents(texts, embeddings)
# db.save_local("faiss_index")

# load
db = FAISS.load_local("faiss_index", embeddings)

# %%
from langchain.vectorstores import Chroma

# add
# db = Chroma.from_documents(texts, embeddings, persist_directory="./chroma_db")

# load
db = Chroma(persist_directory="./chroma_db", embedding_function=embeddings)

# %%
query = "How to Animation Skeletal Characters object"
docs = db.similarity_search(query, k=10)
docs[:3]
# Out:
# [Document(page_content="![](./../../Images/animating-characters-and-objects/BannerImage.png) \n\n# Animating Characters and Objects\n\n## Explore Unreal Engine's animation tools and editors for working with 2D and 3D characters and objects.\n\n\n\nOn this page\n\n\n* [Skeletal Mesh Animation](#skeletalmeshanimation)\n* [Sequencer](#sequencer)\n* [Control Rig](#controlrig)\n* [Paper 2D](#paper2d)\n\nYou can use **Unreal Engine**'s suite of powerful animation tools and editors to create character and object runtime animation systems, rendered cinematic content, and author new animation content directly in the engine.\n\n## Skeletal Mesh Animation\n\nWith the [Skeletal Mesh Animation System](../skeletal-mesh-animation-system-in-unreal-engine), you can create robust animation systems for characters and objects within Unreal Engine. After importing a skinned mesh object as a [Skeletal Mesh asset](../skeletal-mesh-assets-in-unreal-engine), you can manage its properties and build logic to run dynamic animation content using the [Animation Blueprint](../animation-blueprints-in-unreal-engine) visual scripting editor.\n\nFor more information about the using the **Skeletal Animation System** to animate characters and objects in unreal engine, see the following documentation:\n\n[![TopicImage.png]()\n\n\nSkeletal Mesh Animation System\n\n\nUnreal Engine's system for animation and controlling characters.](../skeletal-mesh-animation-system-in-unreal-engine)", metadata={'source': 'UE5.2_Docs\\Animating Characters and Objects\\index.html', 'title': 'Animating Characters and Objects in Unreal Engine | Unreal Engine 5.2 Documentation'}),
#  Document(page_content="![](./../../Images/animating-characters-and-objects/SkeletalMeshAnimation/BannerImage.png) \n\n# Skeletal Mesh Animation System\n\n## Unreal Engine's system for animation and controlling characters.\n\n\n\nOn this page\n\n\n* [Animation Editors](#animationeditors)\n* [Animation Blueprints](#animationblueprints)\n* [Animation Assets and Features](#animationassetsandfeatures)\n* [Live Link](#livelink)\n* [Debugging and Optimization](#debuggingandoptimization)\n* [Workflow Guides and Examples](#workflowguidesandexamples)\n* [Animation Shortcuts and Tips](#animationshortcutsandtips)\n\nCharacter animations in Unreal Engine are built on the foundation of a **Skeletal Mesh**, a rigged mesh that can be manipulated to create animations. In addition, **Animation Blueprints** can be augmented to Skeletal Meshes to apply logic that governs animation behavior and interactions within levels.\n\nUnreal Engine provides a variety of animation tools to work with Skeletal Meshes to further enhance your animations. This page provides an overview of these primary systems.\n\n![skeletal mesh editor]()", metadata={'source': 'UE5.2_Docs\\Animating Characters and Objects\\Skeletal Mesh Animation System.html', 'title': 'Skeletal Mesh Animation System in Unreal Engine | Unreal Engine 5.2 Documentation'}),
#  Document(page_content='![](./../../Images/animating-characters-and-objects/SkeletalMeshAnimation/Persona/skeleton-editor/BannerImage.png) \n\n# Skeleton Editor\n\n## An in depth look at the Skeleton Editor mode in Unreal Engine.\n\n\n\nOn this page\n\n\n* [Toolbar](#toolbar)\n* [Skeleton Tree / Retarget Sources](#skeletontree/retargetsources)\n\n\t+ [Skeleton Tree](#skeletontree)\n\t+ [Bone Manipulation](#bonemanipulation)\n\t+ [Retarget Sources](#retargetsources)\n* [Viewport](#viewport)\n* [Preview Scene Settings / Details](#previewscenesettings/details)\n\n\t+ [Preview Scene Settings](#previewscenesettings)\n\t+ [Details](#details)\n* [Anim Curves / Animation Notifies](#animcurves/animationnotifies)\n\n\t+ [Anim Curves](#animcurves)\n\t+ [Animation Notifies](#animationnotifies)\n\nIn Unreal Engine, [Skeleton Assets](../skeletons-in-unreal-engine) are the foundation for all animation work with **Skeletal Meshes**. The **Skeleton Editor Mode** is the visual editor where you can find the tools and properties to make changes to **Skeleton Assets**.\n\nIn this editor you can manipulate individual bones and bone structures, attach [Skeletal Mesh Sockets](../skeletal-mesh-sockets-in-unreal-engine), and preview any **Animation Curves** and **Animation Notifies** associated with your skeleton. The Skeleton Editor is also where you can find the **Retargeting Manager**, a tool for managing meshes associated with the current Skeleton Asset.\n\nBelow is the Skeleton Editor window with the following tools and Panels:\n\n![skeleton editor overview window]()\n\n1. [Toolbar](../skeleton-editor-in-unreal-engine#toolbar)\n2. [Skeleton Tree / Retarget Sources](../skeleton-editor-in-unreal-engine#skeletontree/retargetsources)\n3. [Viewport](../skeleton-editor-in-unreal-engine#viewport)\n4. [Preview Scene Settings / Details](../skeleton-editor-in-unreal-engine#previewscenesettings/details)\n5. [Anim Curves / Animation Notifies](../skeleton-editor-in-unreal-engine#animcurves/animationnotifies)', metadata={'source': 'UE5.2_Docs\\Animating Characters and Objects\\Skeletal Mesh Animation System_Animation Editors_Skeleton Editor.html', 'title': 'Skeleton Editor in Unreal Engine | Unreal Engine 5.2 Documentation'})]

# %% [markdown]
# # Real World Embeddings
#
# ### Metadata
#
# This dataset is a mirror of the original ArXiv data. Because the full dataset is rather large (1.1TB and growing), this dataset provides only a metadata file in the  `json`  format. This file contains an entry for each paper, containing:
#
# -   `id`: ArXiv ID (can be used to access the paper, see below)
# -   `submitter`: Who submitted the paper
# -   `authors`: Authors of the paper
# -   `title`: Title of the paper
# -   `comments`: Additional info, such as number of pages and figures
# -   `journal-ref`: Information about the journal the paper was published in
# -   `doi`: [[https://www.doi.org](Digital](https://www.doi.org]%28digital/)  Object Identifier)
# -   `abstract`: The abstract of the paper
# -   `categories`: Categories / tags in the ArXiv system
# -   `versions`: A version history
#
# You can access each paper directly on  [ArXiv](https://arxiv.org/)  using these links:
#
# -   `https://arxiv.org/abs/{id}`: Page for this paper including its abstract and further links
# -   `https://arxiv.org/pdf/{id}`: Direct link to download the PDFdownload the PDF

# %%
import pandas as pd
from tqdm.autonotebook import tqdm

# from https://www.kaggle.com/datasets/Cornell-University/arxiv
filename = "./arxiv_datasets/arxiv-metadata-oai-snapshot.json"
fullsize = 2_292_057
batchsize = int(2_292_057/100)+1

# df = pd.read_json(filename, lines=True)
df = pd.concat([chunk for chunk in tqdm(pd.read_json(filename, chunksize=batchsize, lines=True), desc='Loading', total=int(fullsize/batchsize)+1)])
df
# Out:
# Loading:   0%|          | 0/100 [00:00<?, ?it/s]
#                        id           submitter  \
# 0                704.0001      Pavel Nadolsky
# 1                704.0002        Louis Theran
# 2                704.0003         Hongjun Pan
# 3                704.0004        David Callan
# 4                704.0005  Alberto Torchinsky
# ...                   ...                 ...
# 2292052  supr-con/9608008     Ruslan Prozorov
# 2292053  supr-con/9609001  Durga P. Choudhury
# 2292054  supr-con/9609002  Durga P. Choudhury
# 2292055  supr-con/9609003   Hasegawa Yasumasa
# 2292056  supr-con/9609004    Masanori Ichioka
#
#                                                    authors  \
# 0        C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                          Ileana Streinu and Louis Theran
# 2                                              Hongjun Pan
# 3                                             David Callan
# 4                 Wael Abu-Shammala and Alberto Torchinsky
# ...                                                    ...
# 2292052  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2292053  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2292054  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2292055  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2292056  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# 4        From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                    ...
# 2292052  On the origin of the irreversibility line in t...
# 2292053  Nonlinear Response of HTSC Thin Film Microwave...
# 2292054  Critical State Flux Penetration and Linear Mic...
# 2292055  Density of States and NMR Relaxation Rate in A...
# 2292056  Ginzburg Landau theory for d-wave pairing and ...
#
#                                                   comments  \
# 0                  37 pages, 15 figures; published version
# 1                    To appear in Graphs and Combinatorics
# 2                                      23 pages, 3 figures
# 3                                                 11 pages
# 4                                                     None
# ...                                                    ...
# 2292052  19 pages, LaTex, 6 PostScript figures; Author'...
# 2292053  4 pages, LaTeX type, Uses IEEE style files, 60...
# 2292054  20 pages, LaTeX type, Uses REVTeX style files,...
# 2292055  7 pages, 4 PostScript Figures, LaTeX, to appea...
# 2292056  12 pages including 8 eps figs, LaTeX with jpsj...
#
#                                        journal-ref  \
# 0                         Phys.Rev.D76:013009,2007
# 1                                             None
# 2                                             None
# 3                                             None
# 4        Illinois J. Math. 52 (2008) no.2, 681-689
# ...                                            ...
# 2292052                                       None
# 2292053                                       None
# 2292054                                       None
# 2292055                                       None
# 2292056         J. Phys. Soc. Jpn. 66, 204 (1997).
#
#                                 doi         report-no  \
# 0        10.1103/PhysRevD.76.013009  ANL-HEP-PR-07-12
# 1                              None              None
# 2                              None              None
# 3                              None              None
# 4                              None              None
# ...                             ...               ...
# 2292052   10.1103/PhysRevB.54.15530              None
# 2292053           10.1109/77.620744              None
# 2292054   10.1103/PhysRevB.56.11989              None
# 2292055        10.1143/JPSJ.65.3131              None
# 2292056         10.1143/JPSJ.66.204              None
#
#                          categories  \
# 0                            hep-ph
# 1                     math.CO cs.CG
# 2                    physics.gen-ph
# 3                           math.CO
# 4                   math.CA math.FA
# ...                             ...
# 2292052  supr-con cond-mat.supr-con
# 2292053  supr-con cond-mat.supr-con
# 2292054  supr-con cond-mat.supr-con
# 2292055  supr-con cond-mat.supr-con
# 2292056  supr-con cond-mat.supr-con
#
#                                                    license  \
# 0                                                     None
# 1        http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 2292052                                               None
# 2292053                                               None
# 2292054                                               None
# 2292055                                               None
# 2292056                                               None
#
#                                                   abstract  \
# 0          A fully differential calculation in perturba...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 2          The evolution of Earth-Moon system is descri...
# 3          We show that a determinant of Stirling cycle...
# 4          In this paper we show how to compute the $\L...
# ...                                                    ...
# 2292052    We report on measurements of the angular dep...
# 2292053    The non-linear microwave surface impedance o...
# 2292054    The vortex contribution to the dc field (H) ...
# 2292055    We show that the density of states in an ani...
# 2292056    The Ginzburg Landau theory for d_{x^2-y^2}-w...
#
#                                                   versions update_date  \
# 0        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2        [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
# ...                                                    ...         ...
# 2292052  [{'version': 'v1', 'created': 'Mon, 26 Aug 199...  2009-10-30
# 2292053  [{'version': 'v1', 'created': 'Sat, 31 Aug 199...  2016-11-18
# 2292054  [{'version': 'v1', 'created': 'Tue, 3 Sep 1996...  2009-10-30
# 2292055  [{'version': 'v1', 'created': 'Wed, 18 Sep 199...  2009-10-30
# 2292056  [{'version': 'v1', 'created': 'Wed, 25 Sep 199...  2009-10-30
#
#                                             authors_parsed
# 0        [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]
# 2                                       [[Pan, Hongjun, ]]
# 3                                      [[Callan, David, ]]
# 4        [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]
# ...                                                    ...
# 2292052  [[Prozorov, R., ], [Konczykowski, M., ], [Schm...
# 2292053  [[Choudhury, Durga P., , Physics Department, N...
# 2292054  [[Willemsen, Balam A., , Physics Department,\n...
# 2292055  [[Hasegawa, Yasumasa, , Himeji Institute of Te...
# 2292056  [[Enomoto, Naoki, , Okayama Univ.], [Ichioka, ...
#
# [2292057 rows x 14 columns]

# %%
tqdm.pandas()

sdf = df[df['update_date'] > '2023-01-01']
sdf = sdf[sdf.categories.str[:3] == 'cs.']
sdf
# Out:
#                  id            submitter  \
# 55706      803.3946           Adam Smith
# 104832      901.359         Chunhua Shen
# 135819     907.3654  J\'er\^ome Gauthier
# 169585    1001.4297         Andrew Straw
# 185642    1004.3702             Lizhi Du
# ...             ...                  ...
# 1877941  2307.06947     Syed Talal Wasim
# 1877942  2307.06948      Muzammal Naseer
# 1877943  2307.06949        Nataniel Ruiz
# 2041962  cs/0508048        Olivier Danvy
# 2043933  cs/0611111             Tad Hogg
#
#                                                    authors  \
# 55706          Shiva Prasad Kasiviswanathan and Adam Smith
# 104832                           Chunhua Shen and Hanxi Li
# 135819   Jerome Gauthier, Laurent Duval and Jean-Christ...
# 169585   Andrew D. Straw, Kristin Branson, Titus R. Neu...
# 185642                                            Lizhi Du
# ...                                                    ...
# 1877941  Syed Talal Wasim, Muhammad Uzair Khattak, Muza...
# 1877942  Muhammad Uzair Khattak, Syed Talal Wasim, Muza...
# 1877943  Nataniel Ruiz, Yuanzhen Li, Varun Jampani, Wei...
# 2041962  Malgorzata Biernacka and Dariusz Biernacki and...
# 2043933                                           Tad Hogg
#
#                                                      title  \
# 55706    On the `Semantics' of Differential Privacy: A ...
# 104832      On the Dual Formulation of Boosting Algorithms
# 135819   Optimization of Synthesis Oversampled Complex ...
# 169585   Multi-camera Realtime 3D Tracking of Multiple ...
# 185642   A Polynomial time Algorithm for Hamilton Cycle...
# ...                                                    ...
# 1877941  Video-FocalNets: Spatio-Temporal Focal Modulat...
# 1877942  Self-regulating Prompts: Foundational Model Ad...
# 1877943  HyperDreamBooth: HyperNetworks for Fast Person...
# 2041962  An Operational Foundation for Delimited Contin...
# 2043933  Distributed Control of Microscopic Robots in B...
#
#                                                   comments  \
# 55706    Older version of this paper was titled: "A Not...
# 104832   Fixed typos. 16 pages. Published in IEEE Trans...
# 135819                                                None
# 169585   pdfTeX using libpoppler 3.141592-1.40.3-2.2 (W...
# 185642   16 pages. This time, I add a detailed polynomi...
# ...                                                    ...
# 1877941  Project page: https://TalalWasim.github.io/Vid...
# 1877942  Project page: https://muzairkhattak.github.io/...
# 1877943    project page: https://hyperdreambooth.github.io
# 2041962                                           39 pages
# 2043933                                               None
#
#                                                journal-ref  \
# 55706    Journal of Privacy and Confidentiality, 6 (1),...
# 104832                                                None
# 135819   IEEE Transactions on Signal Processing, Octobe...
# 169585                                                None
# 185642                                                None
# ...                                                    ...
# 1877941                                               None
# 1877942                                               None
# 1877943                                               None
# 2041962  Logical Methods in Computer Science, Volume 1,...
# 2043933                                               None
#
#                                  doi report-no  \
# 55706          10.29012/jpc.v6i1.634      None
# 104832         10.1109/TPAMI.2010.47      None
# 135819      10.1109/TSP.2009.2023947      None
# 169585        10.1098/rsif.2010.0230      None
# 185642                          None      None
# ...                              ...       ...
# 1877941                         None      None
# 1877942                         None      None
# 1877943                         None      None
# 2041962      10.2168/LMCS-1(2:5)2005      None
# 2043933  10.1007/978-1-4471-5113-5_8      None
#
#                                   categories  \
# 55706                            cs.CR cs.DB
# 104832                           cs.LG cs.CV
# 135819   cs.IT cs.SY eess.SY math.IT math.OC
# 169585                                 cs.CV
# 185642                                 cs.DS
# ...                                      ...
# 1877941                          cs.CV cs.AI
# 1877942                                cs.CV
# 1877943              cs.CV cs.AI cs.GR cs.LG
# 2041962                          cs.LO cs.PL
# 2043933                          cs.RO cs.MA
#
#                                                    license  \
# 55706    http://arxiv.org/licenses/nonexclusive-distrib...
# 104832   http://creativecommons.org/licenses/by-nc-nd/4.0/
# 135819   http://arxiv.org/licenses/nonexclusive-distrib...
# 169585   http://arxiv.org/licenses/nonexclusive-distrib...
# 185642   http://arxiv.org/licenses/nonexclusive-distrib...
# ...                                                    ...
# 1877941  http://creativecommons.org/licenses/by-nc-sa/4.0/
# 1877942        http://creativecommons.org/licenses/by/4.0/
# 1877943        http://creativecommons.org/licenses/by/4.0/
# 2041962                                               None
# 2043933                                               None
#
#                                                   abstract  \
# 55706      Differential privacy is a definition of "pri...
# 104832     We study boosting algorithms from a new pers...
# 135819     An important issue with oversampled FIR anal...
# 169585     Automated tracking of animal movement allows...
# 185642     Based on the famous Rotation-Extension techn...
# ...                                                    ...
# 1877941    Recent video recognition models utilize Tran...
# 1877942    Prompt learning has emerged as an efficient ...
# 1877943    Personalization has emerged as a prominent a...
# 2041962    We present an abstract machine and a reducti...
# 2043933    Current developments in molecular electronic...
#
#                                                   versions update_date  \
# 55706    [{'version': 'v1', 'created': 'Thu, 27 Mar 200...  2023-01-24
# 104832   [{'version': 'v1', 'created': 'Fri, 23 Jan 200...  2023-05-30
# 135819   [{'version': 'v1', 'created': 'Tue, 21 Jul 200...  2023-01-19
# 169585   [{'version': 'v1', 'created': 'Mon, 25 Jan 201...  2023-02-01
# 185642   [{'version': 'v1', 'created': 'Mon, 12 Apr 201...  2023-07-11
# ...                                                    ...         ...
# 1877941  [{'version': 'v1', 'created': 'Thu, 13 Jul 202...  2023-07-14
# 1877942  [{'version': 'v1', 'created': 'Thu, 13 Jul 202...  2023-07-14
# 1877943  [{'version': 'v1', 'created': 'Thu, 13 Jul 202...  2023-07-14
# 2041962  [{'version': 'v1', 'created': 'Mon, 8 Aug 2005...  2023-06-27
# 2043933  [{'version': 'v1', 'created': 'Tue, 21 Nov 200...  2023-02-03
#
#                                             authors_parsed
# 55706    [[Kasiviswanathan, Shiva Prasad, ], [Smith, Ad...
# 104832                  [[Shen, Chunhua, ], [Li, Hanxi, ]]
# 135819   [[Gauthier, Jerome, ], [Duval, Laurent, ], [Pe...
# 169585   [[Straw, Andrew D., ], [Branson, Kristin, ], [...
# 185642                                     [[Du, Lizhi, ]]
# ...                                                    ...
# 1877941  [[Wasim, Syed Talal, ], [Khattak, Muhammad Uza...
# 1877942  [[Khattak, Muhammad Uzair, ], [Wasim, Syed Tal...
# 1877943  [[Ruiz, Nataniel, ], [Li, Yuanzhen, ], [Jampan...
# 2041962  [[Biernacka, Malgorzata, ], [Biernacki, Darius...
# 2043933                                    [[Hogg, Tad, ]]
#
# [54898 rows x 14 columns]

# %%
from langchain.docstore.document import Document

documents = []
for _, row in sdf.head(20).iterrows():
    text = "# {}\n{}\n".format(row.title, row.abstract)
    row.pop('abstract')
    row.pop('comments')
    row.pop('versions')
    documents.append(Document(page_content=text, metadata=row.to_dict()))

documents[0].metadata
# Out:
# {'id': 803.3946,
#  'submitter': 'Adam Smith',
#  'authors': 'Shiva Prasad Kasiviswanathan and Adam Smith',
#  'title': "On the `Semantics' of Differential Privacy: A Bayesian Formulation",
#  'journal-ref': 'Journal of Privacy and Confidentiality, 6 (1), 2014',
#  'doi': '10.29012/jpc.v6i1.634',
#  'report-no': None,
#  'categories': 'cs.CR cs.DB',
#  'license': 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/',
#  'update_date': '2023-01-24',
#  'authors_parsed': [['Kasiviswanathan', 'Shiva Prasad', ''],
#   ['Smith', 'Adam', '']]}

# %%
from langchain.vectorstores import FAISS

# add
db = FAISS.from_documents(texts, embeddings)
db.save_local("./arxiv_datasets/arxiv_faiss")
